# %% [markdown]
# ## 유연근무제
# - 2025 프로그래머스 코드챌린지 1차 예선
#
# https://school.programmers.co.kr/learn/courses/30/lessons/388351

# %%
def solution(schedules, timelogs, startday):
    weekend = (5, 6)

    startday

    answer = 0
    return answer

schedules = [700, 800, 1100]
timelogs = [[710, 2359, 1050, 700, 650, 631, 659], [800, 801, 805, 800, 759, 810, 809], [1105, 1001, 1002, 600, 1059, 1001, 1100]]
startday = 5

solution(schedules, timelogs, startday)

# %%
def solution(schedules, timelogs, startday):
    answer = 0
    weekend = [6, 7]
    if (startday in weekend):
      pass
    else:
      sche_hour = schedules // 100
      sche_min = schedules % 100

      if (sche_min + 10 > 60):
        # sche_min = 
        pass
      else: 
        pass
      log_hour = timelogs // 100
      log_min = timelogs % 100

      print(f'{sche_hour}, {sche_min}')
      print(f'{log_hour}, {log_min}')
    return answer

solution(855, 905, 5)
# Out:
# 8, 55
# 9, 5
# 0
