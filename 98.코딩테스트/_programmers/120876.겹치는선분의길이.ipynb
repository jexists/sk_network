# %% [markdown]
# # 겹치는 선분의 길이
#
# https://school.programmers.co.kr/learn/courses/30/lessons/120876

# %%
def solution(lines):

    end_list = set()
    for line in lines:
        print(line)
        for x in range(line[0], line[1]+1):
            print(x)
    answer = 0
    return answer

lines = [[0, 1], [2, 5], [3, 9]]
solution(lines)
# Out:
# [0, 1]
# [2, 5]
# [3, 9]
# 0
