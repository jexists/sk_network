# %% [markdown]
# # 표현 가능한 이진트리
#
# https://school.programmers.co.kr/learn/courses/30/lessons/150367

# %%
def solution(numbers):
    answer = []
    binary_list = []
    for num in numbers:
        binary = bin(num)[2:]
        if len(binary) % 2 == 0:
          binary = '0' + binary # 포화 이진트리
        binary_list.append(binary)

    for bina in binary_list:
      flag = True
      for i, b in enumerate(bina):
        if i % 2 == 0:
          pass
        else:
          if b == '1':
            pass
          else:
            answer.append(0)
            flag = False
            break
      if flag == True:
        answer.append(1)


    return answer

# solution([7, 42, 5])
# solution([63, 111, 95])
# solution([15])
# solution([5, 15, 42, 129]) # 0,1,1,0
# solution([5, 15, 42, 129])
# 정답: [0, 1, 1, 0]
# solution([7, 42, 5])
# # 정답: [1, 1, 0]
# solution([63, 111, 95])
# # 정답: [1, 1, 0]
solution([8])
# # 정답: [1]
solution([16])
# 정답: [0]
# Out:
# [0]

# %%
def get_full_binary(binary):
  pass


def solution(numbers):
    answer = []
    binary_list = []
    for num in numbers:
        binary = bin(num)[2:]
        print(len(binary))
    # 포화 길이 패딩

    # 재귀 검사


    return answer

# solution([7, 42, 5])
# solution([63, 111, 95])
solution([5, 15, 42, 129]) # 0,1,1,0
# Out:
# 3
# 4
# 6
# 8
# []

# %%
[7, 42, 5]	[1, 1, 0]
[63, 111, 95]	[1, 1, 0]
