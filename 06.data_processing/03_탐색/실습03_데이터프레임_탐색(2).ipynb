# %% [markdown]
# # [실습] 데이터프레임 탐색 (2)

# %% [markdown]
# 1) pandas 라이브러리를 pd 별칭을 주어 불러오세요.

# %%
import pandas as pd

# %% [markdown]
# 2) 다음 경로의 파일을 읽어 graduate 데이터프레임을 만드세요.
#
# - 파일 경로: 'Graduate_apply.csv'
# - 대소문자를 구분하니 주의하세요.

# %% [markdown]
# **[Graduate_apply 데이터 셋 정보]**
#
# - admit: 입학 승인 여부(0: 불합격, 1: 합격)
# - gre: 시험 성적
# - gpa: 학점
# - rank: 대학 순위

# %%
path = './../00_data/Graduate_apply.csv'

graduate = pd.read_csv(path)

# %% [markdown]
# 3) 상위 10개 행을 확인하세요.

# %%
graduate.head(10)
# Out:
#    admit  gre   gpa  rank
# 0      0  380  3.61     3
# 1      1  660  3.67     3
# 2      1  800  4.00     1
# 3      1  640  3.19     4
# 4      0  520  2.93     4
# 5      1  760  3.00     2
# 6      1  560  2.98     1
# 7      0  400  3.08     2
# 8      1  540  3.39     3
# 9      0  700  3.92     2

# %% [markdown]
# 4) 행과 열의 개수를 확인하세요.

# %%
graduate.shape
# Out:
# (400, 4)

# %% [markdown]
# 5) 각 열의 값 개수와 데이터 형식등을 한 번에 확인하세요.

# %%
graduate.info
# Out:
# <bound method DataFrame.info of      admit  gre   gpa  rank
# 0        0  380  3.61     3
# 1        1  660  3.67     3
# 2        1  800  4.00     1
# 3        1  640  3.19     4
# 4        0  520  2.93     4
# ..     ...  ...   ...   ...
# 395      0  620  4.00     2
# 396      0  560  3.04     3
# 397      0  460  2.63     2
# 398      0  700  3.65     2
# 399      0  600  3.89     3
#
# [400 rows x 4 columns]>

# %% [markdown]
# 6) 기초통계정보를 확인하세요.

# %%
graduate.describe()
# Out:
#             admit         gre         gpa       rank
# count  400.000000  400.000000  400.000000  400.00000
# mean     0.317500  587.700000    3.389900    2.48500
# std      0.466087  115.516536    0.380567    0.94446
# min      0.000000  220.000000    2.260000    1.00000
# 25%      0.000000  520.000000    3.130000    2.00000
# 50%      0.000000  580.000000    3.395000    2.00000
# 75%      1.000000  660.000000    3.670000    3.00000
# max      1.000000  800.000000    4.000000    4.00000

# %% [markdown]
# 7) 범주형 값을 갖는 rank 열의 고유값과 그들의 개수를 확인하세요.

# %%
graduate['rank'].value_counts()
# Out:
# rank
# 2    151
# 3    121
# 4     67
# 1     61
# Name: count, dtype: int64

# %% [markdown]
# 8) gre, gpa 열의 평균값을 한 번에 확인하세요.

# %%
graduate.mean('gre','gpa')
# Out:
# C:\Users\playdata2\AppData\Local\Temp\ipykernel_9480\2266444292.py:1: Pandas4Warning: Starting with pandas version 4.0 all arguments of mean will be keyword-only.
#   graduate.mean('gre','gpa')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 graduate.mean('gre','gpa')
#
# File d:\sk_network\06_dp\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File d:\sk_network\06_dp\.venv\Lib\site-packages\pandas\core\frame.py:14461, in DataFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   14380 @deprecate_nonkeyword_arguments(Pandas4Warning, allowed_args=["self"], name="mean")
#   14381 def mean(
#   14382     self,
#    (...)  14386     **kwargs,
#   14387 ) -> Series | Any:
#   14388     """
#   14389     Return the mean of the values over the requested axis.
#   14390
#    (...)  14459     dtype: float64
#   14460     """
# > 14461     result = super().mean(
#   14462         axis=axis, skipna=skipna, numeric_only=numeric_only, **kwargs
#   14463     )
#   14464     if isinstance(result, Series):
#   14465         result = result.__finalize__(self, method="mean")
#
# File d:\sk_network\06_dp\.venv\Lib\site-packages\pandas\core\generic.py:11831, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11823 def mean(
#   11824     self,
#   11825     *,
#    (...)  11829     **kwargs,
#   11830 ) -> Series | float:
# > 11831     return self._stat_function(
#   11832         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11833     )
#
# File d:\sk_network\06_dp\.venv\Lib\site-packages\pandas\core\generic.py:11783, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11780 assert name in ["median", "mean", "min", "max", "kurt", "skew"], name
#   11781 nv.validate_func(name, (), kwargs)
# > 11783 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
#   11785 return self._reduce(
#   11786     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11787 )
#
# File d:\sk_network\06_dp\.venv\Lib\site-packages\pandas\util\_validators.py:266, in validate_bool_kwarg(value, arg_name, none_allowed, int_allowed)
#     263     good_value = good_value or isinstance(value, int)
#     265 if not good_value:
# --> 266     raise ValueError(
#     267         f'For argument "{arg_name}" expected type bool, received '
#     268         f"type {type(value).__name__}."
#     269     )
#     270 return value
#
# ValueError: For argument "skipna" expected type bool, received type str.

# %% [markdown]
# 9) gre 열을 기준으로 오름차순으로 정렬해 확인하세요.

# %% [markdown]
# 10) 다음 요구사항에 따라 구문을 순서대로 작성하고 확인하세요.
#
# - rank 열을 기준으로 오름차순, rank 열 값이 같으면 gpa 열을 기준으로 내림차순으로 정렬해 tmp 테이터프레임으로 선언하세요.
# - tmp 데이터프레임 인덱스 초기화 하세요.(단, 기존 인덱스 제거)
# - tmp 데이터프레임을 확인하세요.
