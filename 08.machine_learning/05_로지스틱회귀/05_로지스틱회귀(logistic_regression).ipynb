# %% [markdown]
# # 1.환경 준비
#
# - 데이터 : Iris.csv
# - Logistic Regression 알고리즘으로 모델링한다.
# - 로지스틱 회귀는 확률 값을 자연스럽게 제공하므로, 확률 분포를 기반으로 그래프를 그리기 적합한 모델이다.

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format='retina'

# %%
path = 'data/iris.csv'
df = pd.read_csv(path)

# %% [markdown]
# # 2.데이터 이해

# %%
# 상위 몇 개 행 확인
df.head()

# %%
df.describe()

# %%
df['Species'].value_counts()

# %%
numeric_df=df.select_dtypes(include=['number'])

# %%
numeric_df.corr()

# %% [markdown]
# # 3.데이터 전처리

# %% [markdown]
# **1) x, y 분리**

# %% [markdown]
# **2) 학습용, 평가용 데이터 분리**

# %% [markdown]
# # 4.모델링

# %%
# 1단계: 불러오기

# %%
# 2단계: 선언하기

# %%
# 3단계: 학습하기

# %%
# 4단계: 예측하기

# %%
# 5단계 평가하기
