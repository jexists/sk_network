# %% [markdown]
# # 실습 내용
#
# - Grid Search로 Decision Tree 알고리즘 모델을 튜닝한다.

# %% [markdown]
# # 1.환경 준비

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format='retina'

# %%
# 데이터 읽어오기
path = '/content/mobile_cust_churn.csv'
df = pd.read_csv(path)

# %%
df.head()

# %% [markdown]
# # 2.데이터 이해

# %%
# 상위 몇 개 행 확인
df.head()

# %%
# 기술통계 확인
df.describe()

# %% [markdown]
# # 3.데이터 전처리

# %% [markdown]
# **1) 변수 제거**

# %%
# 제거 대상: id

# 변수 제거


# 확인

# %% [markdown]
# **2) x, y 분리**

# %%
# Target 설정


# 데이터 분리

# %% [markdown]
# **3) 가변수화**

# %%
# 가변수화 대상: REPORTED_SATISFACTION, REPORTED_USAGE_LEVEL, CONSIDERING_CHANGE_OF_PLAN


# 가변수화


# 확인

# %% [markdown]
# **4) 학습용, 평가용 데이터 분리**

# %%
# 모듈 불러오기


# 7:3으로 분리

# %% [markdown]
# # 4.성능 예측
#
# - k-Fold Cross Validation을 사용해 모델의 성능을 예측한다.

# %%
# 불러오기

# %%
# 선언하기

# %%
# 성능예측

# %%
# 결과확인

# %% [markdown]
# # 5.모델 튜닝
#
#
# - Grid Search로 튜닝을 진행한다.

# %% [markdown]
# **1) 모델 튜닝**

# %%
# 파라미터 선언
  # max_depth: range(1, 51)


# Random Search 선언
  # cv=5
  # scoring='accuracy'

# %%
# 학습하기

# %% [markdown]
# **2) 결과 확인**

# %%
# mean_test_score 확인

# %%
# 최적 파라미터

# %%
# 최고 성능

# %% [markdown]
# **3) 변수 중요도**

# %%
# 변수 중요도

# %% [markdown]
# # 6. 성능 평가
#
# - 학습을 통해 예상한 성능과 실제 평가에 따른 성능은 차이가 있을 수 있다.

# %%
# 예측하기

# %%
# 평가하기
