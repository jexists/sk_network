# %% [markdown]
# # 실습 내용
#
# - 데이터 : airquality.csv
# - KNN 알고리즘을 사용해 모델링한다.

# %% [markdown]
# # 1.환경 준비

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format='retina'

# %%
path = './../00_data/airquality.csv'
df = pd.read_csv(path)

# %% [markdown]
# # 2.데이터 이해

# %%
df.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0   41.0    190.0   7.4    67      5    1
# 1   36.0    118.0   8.0    72      5    2
# 2   12.0    149.0  12.6    74      5    3
# 3   18.0    313.0  11.5    62      5    4
# 4    NaN      NaN  14.3    56      5    5

# %%
df.describe()
# Out:
#             Ozone     Solar.R        Wind        Temp       Month         Day
# count  116.000000  146.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.129310  185.931507    9.957516   77.882353    6.993464   15.803922
# std     32.987885   90.058422    3.523001    9.465270    1.416522    8.864520
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     18.000000  115.750000    7.400000   72.000000    6.000000    8.000000
# 50%     31.500000  205.000000    9.700000   79.000000    7.000000   16.000000
# 75%     63.250000  258.750000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000

# %%
df.isna().sum()
# Out:
# Ozone      37
# Solar.R     7
# Wind        0
# Temp        0
# Month       0
# Day         0
# dtype: int64

# %% [markdown]
# # 3.데이터 전처리

# %% [markdown]
# **1) 결측치 처리**
#
# - 결측치가 있으면 제거하거나 적절한 값으로 채운다.
# - 시계열 데이터이므로 선형보간법으로 채운다.

# %%
df.interpolate(method='linear', inplace=True)
# Out:
#      Ozone     Solar.R  Wind  Temp  Month  Day
# 0     41.0  190.000000   7.4    67      5    1
# 1     36.0  118.000000   8.0    72      5    2
# 2     12.0  149.000000  12.6    74      5    3
# 3     18.0  313.000000  11.5    62      5    4
# 4     23.0  308.333333  14.3    56      5    5
# ..     ...         ...   ...   ...    ...  ...
# 148   30.0  193.000000   6.9    70      9   26
# 149   22.0  145.000000  13.2    77      9   27
# 150   14.0  191.000000  14.3    75      9   28
# 151   18.0  131.000000   8.0    76      9   29
# 152   20.0  223.000000  11.5    68      9   30
#
# [153 rows x 6 columns]

# %%
df.isna().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %% [markdown]
# **2) 변수 제거**

# %%
drop_cols = ['Month', 'Day']
df.drop(drop_cols, axis=1, inplace=True)

df.head()
# Out:
#    Ozone     Solar.R  Wind  Temp
# 0   41.0  190.000000   7.4    67
# 1   36.0  118.000000   8.0    72
# 2   12.0  149.000000  12.6    74
# 3   18.0  313.000000  11.5    62
# 4   23.0  308.333333  14.3    56

# %% [markdown]
# **3) x, y 분리**

# %%
target = 'Ozone'

X = df.drop(target, axis=1)
y = df[target]

# %% [markdown]
# **4) 학습용, 평가용 데이터 분리**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=0.3,
                                                    random_state=1)

# %% [markdown]
# **5) 정규화**

# %%
from sklearn.preprocessing import MinMaxScaler

# 정규화
scaler = MinMaxScaler()
scaler.fit(X_train)
X_train = scaler.transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # 4.모델링

# %%
# 1단계: 불러오기
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# %%
# 2단계: 선언하기
model = KNeighborsRegressor()

# %%
# 3단계: 학습하기
model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
# 4단계 예측하기
y_pred = model.predict(X_test)

# %%
# 5단계: 평가하기
print('MAE:', mean_absolute_error(y_test,y_pred))
print('R2-score:', r2_score(y_test,y_pred))
# Out:
# MAE: 18.683375682288727
# R2-score: 0.2877906019226045

# %% [markdown]
# # 5.기타

# %% [markdown]
# **1) 학습 성능**
#
# - n_neighbors 값을 학습 데이터 건수로 하면 가장 단순한 모델, 즉 평균이 된다.
# - n_neighbors 값을 1로 하면 가장 복잡한 모델이 되며 정답, 즉 y_train 값을 외운 결과가 된다.
# - n_neighbors 값에 따라 학습 데이터를 얼마나 깊이 있게 학습했는지 확인한다.

# %%
# 모델 복잡도
k_num = [1,2,3,4,8,20,80,len(X_train)]

# %%
# 이웃 수 k에 따른 모델 복잡도를 비교
plt.figure(figsize=(10,8))
for i, n in enumerate(k_num):
    model = KNeighborsRegressor(n_neighbors=n)

    model.fit(X_train, y_train)
    y_pred = model.predict(X_train)


    plt.subplot(3,3, i+1)
    plt.plot(y_train.values, label='y_train')
    plt.plot(y_pred, label='y_pred')
    plt.title(f'k={n}')
    plt.legend()
    plt.ylabel('Ozone')

plt.tight_layout()
plt.show()

# %% [markdown]
# **2) 평가 성능**
#
# - n_neighbors 값에 따라 평가 성능이 어느 정도 인지 확인한다.

# %%
# 모델 복잡도
k_num2 = [1,2,3,4,8,20,50,80,len(X_train)]

# %%
plt.figure(figsize=(10,8))
for i, n in enumerate(k_num2):
    model = KNeighborsRegressor(n_neighbors=n)
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    r2 = r2_score(y_test,y_pred)

    plt.subplot(3,3, i+1)
    plt.plot(y_test.values, label='y_test')
    plt.plot(y_pred, label='y_pred')
    plt.title(f'k={n}, R2={r2:.2f}')
    plt.legend()
    plt.ylabel('Ozone')

plt.tight_layout()
plt.show()
