# %% [markdown]
# # **1. 파이썬(Python) 개발 환경**
#
# - **개발 환경**: 코딩, 디버깅, 배포 등 프로그램을 개발하는 일련의 과정을 하나의 프로그램 안에서 수행할 수 있도록 해주는 통합적인 환경
# - 온라인 개발 환경은 **웹 브라우저**만 있으면 사용할 수 있다는 점에서 편리하게 사용할 수 있다.
#   - 간단한 프로그램을 작성하여 테스트할 때 유용하다.
#   - 프로그램 실행 결과를 저장할 때는 불편함이 있다.

# %%
print('hello world')
# Out:
# hello world

# %% [markdown]
# ## **1.1. Google Colab(온라인환경)**
#
# - 구글(Google) 계정만 있다면 무료로 사용할 수 있는 개발 환경
# - **Google Colab 시작하기**: https://colab.research.google.com/
# - [+코드] 버튼을 클릭하여 코드 셀을 추가하고, 파이썬 코드를 작성할 수 있다.
# - [Shift + Enter]를 입력하여 현재 코드 셀의 파이썬 코드를 실행할 수 있다.

# %% [markdown]
# ## **1.2. Visual Studio Code(로컬환경)**
#
# - Visual Studio Code는 파이썬을 포함한 다양한 프로그래밍 언어를 지원하며, 무료인 개발 환경
# - Visual Studio Code 다운로드 경로: https://code.visualstudio.com/
#   - [Download for Windows] 버튼을 눌러 무료로 설치할 수 있다.

# %% [markdown]
# # **2. 파이썬 시작하기**

# %% [markdown]
# ## 2.1. **Python이란?**
#
# - 창시자는 네덜란드의 프로그래머 귀도 반 로섬(Guido van Rossum)
#     - 1989년 크리스마스 주에, 연구실이 닫혀있어서 심심한 김에 만든 프로그래밍 언어
#     - 1991년 Python 최초 발표
# - 능력 있는 기술자들은 대부분 심심할 때, 혹은 실수로 걸작을 만듦
# - Python이라는 이름은 귀도가 즐겨 보던 영국의 6인조 코미디 그룹 몬티 Python에서 따왔다고 함
# - 문법이 매우 쉬워서 초보자들이 프로그래밍을 할 때 추천되는 언어
# - 학습용으로 좋은 언어인 동시에 실사용률과 생산성도 높은 대단히 강력한 언어
# - 구글에서 만들어진 소프트웨어의 50% 이상이 파이썬

# %% [markdown]
# ## 2.2. Python 버전 확인

# %%
# 버전 확인
import sys
print(sys)
print(sys.version)
# Out:
# <module 'sys' (built-in)>
# 3.13.12 (tags/v3.13.12:1cbe481, Feb  3 2026, 18:22:25) [MSC v.1944 64 bit (AMD64)]

# %% [markdown]
# # 3.자료형과 연산자

# %% [markdown]
# ## 3.1.시작하기
#
# - 변수, 키워드, 식별자, 주석에 대한 개념 세우기

# %% [markdown]
# ### 3.1.1.변수(Variables)

# %% [markdown]
# - **변수**는 값을 담는 그릇 또는 상자라고 할 수 있다.
# - 이후 연산 등의 **재사용** 목적을 위해 값을 담아 두는 존재
# - **변수 = 값** 형태로 값을 대입하면서 변수를 선언
# - 변수 이름은 그 의미를 알 수 있게 적절한 단어를 사용
# - 변수에 대입된 값에 의해 변수의 자료형(=데이터 형식)이 결정
# - 코드셀에 변수 이름만 입력하고 실행하면 변수의 값이 표시됨

# %%
# 변수 선언
name = '홍길동'
age = 30
item_count = 15

# 변수 값 확인
age
# Out:
# 30

# %% [markdown]
# - 변수를 일부러 제거하지 않는 한 코드 셀이 달라도 변수는 계속 유지

# %%
# 변수 값 변경
age = age + 1

# 변수 값 확인
age
# Out:
# 31

# %% [markdown]
# - 변수 이름만 봐서는 데이터 형식(정수, 실수, 문자열 등)을 알 수 없다.
# - 데이터 형식은 **type()**  함수로 확인

# %%
# 데이터 형식 확인
type(age)
# Out:
# int

# %%
# 문자열 형식
type(name)
# Out:
# str

# %%
# 문자열과 숫자 더하기 오류 확인
result = name + age
print(result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 문자열과 숫자 더하기 오류 확인
# ----> 2 result = name + age
#       3 print(result)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ### 3.1.2.Python 키워드(Keywords)
#
# - Python 키워드는 Python 자체 사용 목적으로 이미 예약된 문자열
# - Python 키워드를 변수나 함수 이름, 즉 **식별자**로 사용할 수 없음
# - 다음이 Python 키워드이며, Python 버전이 바뀌면서 달라질 가능성이 있음

# %% [markdown]
# - keyword 라이브러리를 사용해 Python 현재 버전의 키워드를 확인할 수 있다.

# %%
# 키워드 확인
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# ### 3.1.3.식별자(Identifier)
#
# - **식별자** : 변수 또는 함수 등에 이름을 붙이기 위해 사용하는 단어
# - 식별자는 다음과 같은 **규칙**을 갖는다.
#  - 키워드를 사용할 수 없음
#  - 언더 바(_)를 제외하고는 특수 문자를 사용할 수 없음
#  - 공백을 포함해서는 안됨
#  - 숫자로 시작하면 안됨
# - 다음은 올바른 식별자의 예
#  - age, score, member, member_01, num01, num02
# - 다음은 올바르지 않은 식별자의 예
#  - if, while, 123, 3Member, My Score, a+b
# - 대/소문자를 구분하므로 대/소문자 여부에 신경쓰지 않게 **소문자 사용을 권고**함.
# - 또한 언더 바와 영어 단어를 적절히 섞어 가독성이 좋게 하기를 권고함.
#  - 안 좋은 예: myname, englishscore
#  - 좋은 예: my_name, english_score

# %% [markdown]
# ### 3.1.4.주석(Comments)
#
# -  **주석** : 코드 실행과는 상관없이 설명을 위해 작성된 문자열
# - 소스에 대한 충분한 설명, 즉 주석을 충분히 작성하기를 권고함
# - Python에서 주석은 #으로 시작하며, 다음 구문에서 **# 변수 선언** 부분이 주석이다.

# %%
# 변수 선언

# 설명을 적음

# %% [markdown]
# ## 3.2.숫자형 자료형
# - Python은 다양한 형태의 값을 저장하고 처리할 수 있도록 여러가지 자료형을 제공한다.
# - 우선 가장 기본이 되는 숫자형 데이터 중 정수형, 실수형에 대해 살펴보자

# %% [markdown]
# ### 3.2.1.정수형과 실수형

# %% [markdown]
# **1) 정수형**
#
# - 음의 정수, 0, 양의 정수(자연수)를 합해 정수형이라 한다.
# - **정수 끼리의 연산**결과가 **실수가 될 수 있다.**(특히 나누기 연산, 5 / 2 = 2.5)
# - 변수 이름을 보고 자료형을 알 수는 없다.
# - **type()** 함수로 어떤 자료형인지 확인해야 한다.

# %%
# 정수형 변수
x = 5

# 확인
print(x)
print(type(x))
# Out:
# 5
# <class 'int'>

# %% [markdown]
# **2) 실수형**
#
# - 소수점을 표시할 수 있는 숫자를 실수형이라고 한다.
# - 실수 데이터와 정수 데이터 사이에서 연산을 수행하는 경우, 데이터의 **형 변환(정수 → 실수)**이 일어난다.

# %%
# 실수형 변수
y = 2.5

# 자료형 확인
print(type(y))

# 연산 확인
print(y, y+1, y**2)
# Out:
# <class 'float'>
# 2.5 3.5 6.25

# %%
# 정수형 변수
z = 123

# 정수 사이의 연산
num = z/4

# 확인
print(num)
print(type(num))
# 자연스러운 형변환
# Out:
# 30.75
# <class 'float'>

# %% [markdown]
# ## 3.3.연산자(Operators)
#
# - Python은 수식을 **계산(=산술)**하거나 값을 **비교**하거나 **대입**하는 등의 다양한 **연산자**를 가지고 있다.

# %% [markdown]
# ### 3.3.1.산술 연산자(Arithmetic Operators)
#
# - **사칙연산(+, -, *, /)**은 일반적으로 알고 있는 연산 방법(더하기 빼기 등)과 같다.
# - 값을 더하거나 빼는 등의 처리를 하는 연산자를 **산술 연산자**라고 부름
# - **정수**는 소수점이 없는 숫자이며, 음의 정수, 0, 양의 정수를 갖는다. *ex) -10, 0, 15*
# - **실수**는 소수점이 있는 숫자이다. *ex) 123.45*

# %%
# 정수형 변수
num1 = 26
num2 = 5

# %% [markdown]
# **1) 사칙 연산자**

# %%
# 더하기
num1 + num2
# Out:
# 31

# %%
# 빼기
num1 - num2
# Out:
# 21

# %%
# 곱하기
num1 * num2
# Out:
# 130

# %%
# 나누기
num1 / num2
# Out:
# 5.2

# %% [markdown]
# **2) 몫, 나머지, 제곱 연산자**

# %%
# 몫
num1 // num2
# Out:
# 5

# %%
# 나머지
num1 % num2
# Out:
# 1

# %%
# 제곱
num1 ** num2
# Out:
# 11881376

# %% [markdown]
# **3) 연산자 활용**
#
# - **% 연산자**는 짝수 또는 홀수 인지를 판단할 때 사용하는 경우가 많다.
# - 조건문(if 문)을 아직 배우지 않았지만 다음 코드의 의미는 파악이 될 것이다.

# %%
# 변수 선언
num3 = 20

# 짝/홀수 판단
if num3 % 2 == 0:
    result = "짝수"
else:
    result = "홀수"
# 들여쓰기 중요 (없는경우 오류)

# 확인
result
# Out:
# '짝수'

# %% [markdown]
# - **// 연산자**는 10 단위 또는 100 단위 등의 수를 구할 때 사용하는 경우가 많다.

# %%
# 변수 선언
age = 26

# 10으로 나눈 몫을 구한 후 10 곱하기
age = age // 10 * 10

# 확인
age
# Out:
# 20

# %% [markdown]
# **<연습문제>**

# %% [markdown]
# [문1] 다음 요구사항에 맞는 코드를 작성하고 실행하시오.

# %%
# 128을 7로 나눈 몫

a = 128
b = 7

a // b
# Out:
# 18

# %%
# 128를 7로 나눈 나머지

a % b
# Out:
# 2

# %%
7 * 18 + 2
# Out:
# 128

# %% [markdown]
# ### 3.2.2.print() 함수
#
# - 어떤 처리를 위해 미리 작성되어 모듈화된 코드를 **함수(Function)**라고 부른다.
# - 단순 값, 변수의 값, 연산 결과 등을 확인하기 위해 print() 함수를 사용

# %%
# 실수형 변수
c = 10.5
d = 2.5

# %%
# print() 함수를 사용하지 않은 경우
# 맨 밑에 줄만 결과가 나옴
c % d
c // d
# Out:
# 4.0

# %%
# print() 함수를 사용한 경우 #1
# 여러값을 한번에 확인 가능
print(c % d)
print(c // d)
# Out:
# 0.5
# 4.0

# %% [markdown]
# - print() 함수 안에 콤마로 구분해 값을 여러 개 전달할 수 있어 다음과 같이 사용할 수 있다.

# %%
# print() 함수를 사용한 경우 #2
print('c = ', c)
print('d = ', d)
print('c % d = ', c % d)
# Out:
# c =  10.5
# d =  2.5
# c % d =  0.5

# %% [markdown]
# - print() 함수에 sep, end 옵션을 사용할 수도 있다.

# %%
# 구분자 지정
print('hello', 'world')
print('hello', 'world', sep=',')
print('hello', 'world', sep='')
# Out:
# hello world
# hello,world
# helloworld

# %%
# 개행 여부 지정
print('hello','world', end='\n')
print('hello','world')

print('-----')

print('hello','world', end=' ')
print('hello','world')
# Out:
# hello world
# hello world
# -----
# hello world hello world

# %% [markdown]
# **<연습문제>**

# %% [markdown]
# [문1] name, age 변수에 본인의 이름과 나이를 대입하고 코드를 실행하시오.

# %%
# 변수 선언
name = '홍길동'
age = 30

# %%
# 나이 빼기
age = age - 10

# %%
# 값 확인 #1
print('이름: ', name)
print('나이: ', age)
# Out:
# 이름:  홍길동
# 나이:  20

# %%
# 값 확인 #2

print('이름: ', name, '/', '나이: ', age)
# Out:
# 이름:  홍길동 / 나이:  20

# %% [markdown]
# [문2] 다음 변수들의 합계와 평균을 total_score, avg_score 변수에 담아 출력하는 코드를 작성하시오.

# %%
# 정수형 변수
score1 = 53
score2 = 94
score3 = 12
score4 = 88
score5 = 37

# 합계 구하기
total = score1 + score2 + score3 + score4 + score5

# 평균 구하기
avg = total / 5

# 출력
print('합계 ', total)
print('평균 ', avg)
# Out:
# 합계  284
# 평균  56.8

# %% [markdown]
# ### 3.2.3.복합 연산자(Assignment Operators)
#
# - **연산과 대입을 동시**에 수행할 수 있는 연산자를 복합 연산자라고 부른다.
# - 구문은 짧으나 가독성이 떨어지므로 너무 많이 사용하면 오히려 복잡해 질 수 있다.

# %%
# 정수형 변수 선언
num4 = 10


# 복합 대입 연산자 사용
num4 += 10
# print(num4) #20

num4 -= 2
# print(num4) #18

num4 *= 3
# print(num4) #54

num4 /= 5
# print(num4) #10.8


# 확인
print(num4)
# Out:
# 10.8

# %% [markdown]
# - 위 구문은 다음 구문과 같다.

# %%
# 정수형 변수 선언
num4 = 10

# 복합 대입 연산자 사용 안함
num4 = num4 + 10

num4 = num4 - 2

num4 = num4 * 3

num4 = num4 / 5


# 확인
print(num4)
# Out:
# 10.8

# %% [markdown]
# ## 3.4.[참고] 날짜 시간 자료형
#
# - Python은 날짜와 시간 관련 자료형을 제공하지 않는다.
# - 필요하다면 **datetime** 라이브러리를 불러와 사용해야 한다.

# %%
# 라이브러리 불러오기
from datetime import datetime

# 현재 날짜와 시간 얻기
dt = datetime.now()
dt
# Out:
# datetime.datetime(2026, 3, 30, 10, 20, 18, 658958)

# %%
# 날짜 시간 정보 표시
print('날짜와 시간', dt)


print('연도', dt.year)
print('월', dt.month)
# Out:
# 날짜와 시간 2026-03-30 10:20:18.658958
# 연도 2026
# 월 3
