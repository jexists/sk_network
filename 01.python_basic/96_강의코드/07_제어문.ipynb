# %% [markdown]
# # 7.제어문(Control Statements)
#
# - **조건 처리**나 **반복 처리**를 통해 코드의 실행 흐름을 제어할 수 있다.
# - Python 제어문은 **들여쓰기로 블럭을 지정**하니 이에 주의해야 한다.
# - 다양한 로직 작성을 위해 필히 익혀야 하는 내용이다.
# - 확장 문법을 알아두면 편리하다.

# %% [markdown]
# ## 7.1.if 문
#
# - 가장 대표적인 제어문이다.
# - 특정 조건에 맞는 경우에만 코드를 실행한다.

# %% [markdown]
# **1) 단순 if 문**
#
# - 조건이 참인 경우만 처리한다.
# - 조건이 거짓인 경우는 아무 처리도 하지 않는다.

# %%
my_score = 73

# 80보다 크거나 같으면 10 더하기

# %%
score_list = [75, 80, 70, 95, 90]

# 리스트에 요소가 있으면 출력, 없으면 말고

# %% [markdown]
# **2) if ~ else 문**
#
# - 조건이 참인 경우와 참이 아닌 경우 각각 처리한다.

# %%
my_score = 73

# 80보다 크거나 같으면 Pass, 아니면 Fail

# %%
score_list = [75, 80, 70, 95, 90]

# 리스트에 요소가 있으면 출력, 없으면 '요소 없음' 출력

# %% [markdown]
# - 처리할 구문이 한 줄이라면 다음과 같이 작성할 수 있다.

# %% [markdown]
# - 처리할 구문이 없거나 이후에 작성할 목적으로 **pass**를 사용할 수 있다.

# %% [markdown]
# **3) if ~ elif ~ else 문**
#
# - 여러 조건 중에서 참인 경우 각각 처리하고, 그렇지 않은 경우 다음 조건으로 넘어가 처리한다.

# %%
my_score = 76

# 점수에 따른 학점 주기

# %% [markdown]
# 4) 조건문 오류
# - 자주 실수하는 오류에는 콜론 오류, 들여쓰기 오류 등이 있다.

# %% [markdown]
# **<연습문제>**

# %% [markdown]
# [문1] 다음 셀을 수행해 오늘 요일이 숫자로 표시됨을 확인하고, 다음 셀을 완성해 보시오.

# %%
# 오늘의 요일 확인
from datetime import datetime
dt = datetime.now()               # datetime.now() 메소드를 사용하여 현재 시간을 dt 변수에 저장
week_num = dt.weekday()           # 현재 요일을 숫자로 가져옴. (0=월, 1=화, ..., 6=일)
week_num
# Out:
# 6

# %%
# 숫자로된 요일이 '월' ~ '일' 문자로 표시되게 조건문 작성

# %%
# [참고] 리스트 활용

# %% [markdown]
# [문2] score 값에 따라 등급을 주는 다음의 조건문을 완성하시오.
# - 95점 이상 A+. 90점 이상 A, 85점 이상 B+, 80점 이상 B, 75점 이상 C+. 70점 이상 C, 60점 이상 D, 60점 미만 F

# %%
score1 = 72
score2 = 90
score3 = 76

my_score = score1

# 조건 처리

# %% [markdown]
# [문3] score1, score2, score3 점수에 대하여 다음 조건이 처리되도록 조건문을 완성하시오.
# - 하나라도 60점 이하거나 점수의 평균이 70점 이하이면 Fail
# - 그렇지 않은 경우에는 Pass

# %%
score1 = 60
score2 = 100
score3 = 76

# 조건 처리

# %% [markdown]
# [문4] 위 미완성 코드를 if 한번과 else 한번으로 수정해보시오.

# %% [markdown]
# ## 7.2.while 문
#
# - 조건문이 True인 동안 while문 안의 문장이 반복해서 실행된다.
# - 특정 상황에서 반복을 중지하게 while 문 안에서 조건을 제어한다.

# %% [markdown]
# **1) 일반 while 문**

# %% [markdown]
# - 문자열 길이를 반환하는 len() 함수가 리스트의 요소 개수를 반환한다.

# %%
fruits = ['apple', 'banana', 'cherry']

# %% [markdown]
# **2) 무한루프 다루기**
#
# - break 문: 반복문 안에서 특정 조건이 되어 반복문을 빠져 나올 때 사용한다.
# - continue 문: 반복문을 중단시키지 않고 다음 반복으로 넘어갈 때 사용한다.

# %%
total, i = 0, 0

# 100까지 짝수 합 구하기

# %% [markdown]
# **<연습문제>**

# %% [markdown]
# [문1] 다음 셀의 코드는 위 셀(2. 무한루프 다루기)의 코드와 같다. 내용 중에서 굳이 필요 없는 두 줄이 있다. 찾아서 제거해 보시오.

# %%
# 변수 선언
total, i = 0, 0

# 100까지 짝수 합 구하기
while True:
    i += 1

    # 100보다 크면 종료
    if i > 100:
        break

    # 짝수인지 판별
    if i % 2 == 0:
        total += i
    else:
        continue

total

# %% [markdown]
# - input() 함수를 사용해 사용자의 입력을 받을 수 있다.
# - isnumeric() 메소드: 숫자이면 True 아니면 False 반환한다.

# %%
# 문자를 입력하면 continue, 0을 입력하면 break, 아니면 10으로 나눈 나머지 표시
while True:
    response = input('숫자를 입력하세요(0 = 종료):')
    if not response.isnumeric():
        continue
    if int(response) == 0:
        break
    result = int(response) % 10
    print("{} 나누기 10의 나머지는 {}입니다.".format(response, result))

# %% [markdown]
# ## 7.3.for 문
#
# - 첫번째 값부터 마지막 값까지 하나씩 가져가면서 처리한다.

# %% [markdown]
# **<연습문제>**

# %% [markdown]
# [문1] 다음 셀을 코드를 수정해 1부터 10까지 짝수의 합을 구해 보시오.

# %%
# 1부터 10까지 짝수의 합

# %% [markdown]
# [문2] for문과 range를 사용하여 1 ~ 100까지의 합을 구하시오.

# %%
# 1부터 100까지 합

# %% [markdown]
# [문3] for 문과 range를 사용하여 1 ~ 100까지 수 중 7의 배수를 출력하시오.

# %%
# 1부터 100까지 7의 배수

# %% [markdown]
# ### 7.3.1.리스트와 for 문
#
# - 반복문과 가장 많이 사용되는 자료형이 리스트형이다.

# %% [markdown]
# **1) 기본 반복문**
#
# - 첫 번째 요소부터 마지막 요소까지 코드를 반복 처리한다.

# %%
member = ['유재석', '박명수', '정준하', '노홍철', '정형돈']

# %% [markdown]
# **2) enumerate() 함수 사용**
#
# - 영어 단어 enumerate의 뜻은 '**낱낱이 세다**' 이다.
# - 문자열이나 컨테이너 자료형을 입력받아, 순번과 요소를 포함하는 오브젝트로 반환한다.
# - 순번과 요소를 반환하여 몇 번째, 어느 요소를 처리하고 있는지 확인 가능하다.

# %%
# 순번이 짝수인 경우만 '순번: 이름' 형태로 출력

# %% [markdown]
# **3) 반복문 확장(list comprehension)**
#
# - 이 방법을 사용하면 반복문 코드가 매우 간결해진다.
# - 처음에는 다소 낯설 수 있으나, 이것이 **Python 스러운 문법**이라 할 수 있다.

# %%
# 반복문 확장 문법 #1

# %%
# 반복문 확장 문법 #2
# 반복문 + 조건문: 짝수인 값의 제곱을 구해서 even_squares 리스트에 넣기

# %% [markdown]
# **<연습문제>**

# %% [markdown]
# [문1] 다음 두 셀의 코드를 완성해 보시요.

# %%
my_nums = [10, 22, 30, 41, 56, 60, 71, 80, 90]

# 마지막에 100 추가

# %%
# my_nums 리스트에서 10의 배수만을 뽑아 그 값을 10으로 나눈 정수값을 갖는 새로운 리스트 만들기

# %%
# [심화] 위 구문을 List Comprehension으로 만들어 보기

# %% [markdown]
# [문2] score에서 음수를 제거한 리스트를 score01 변수에 담으시오.

# %%
score = [75, 46, 93, -82, -77, 130, 100, 75, -10]

# %% [markdown]
# [문3] score01에서 100보다 큰 수를 제외한 리스트를 score02 변수에 담으시오.

# %% [markdown]
# [문4] score02 리스트의 요소들 합과 평균을 구하시오.

# %% [markdown]
# [문5] score02 리스트의 각 요소의 값을 10으로 나눈 값을 갖는 리스트 score03을 만드시오.

# %% [markdown]
# [문6] 위 2), 3), 5)번 문제를 모두 반복문 확장 문법(List Comprehension)으로 변환하시오.

# %%
# 2번


# 3번


# 5번

# %% [markdown]
# ### 7.3.2.딕셔너리와 for 문

# %% [markdown]
# **1) 기본 반복문**

# %%
score = {'홍길동': 85, '한사랑': 95, '일지매': 90}

# key와 value 조회

# %% [markdown]
# **2) items() 메소드 사용**
#
# - 딕셔너리를 반복문에 사용할 때 key와 value를 반환해주는 items() 메소드를 많이 사용한다.

# %% [markdown]
# **<연습문제>**

# %% [markdown]
# [문1] 학생 이름과 점수를 갖는 아래 딕셔너리에 대해 반복문을 작성해 다음과 같이 학생들 이름과 점수 합이 출력되게 해보시오.
#
# ~~~
# 홍길동: 350
# 한사랑: 355
# 일지매: 300
# ~~~

# %%
score = {'홍길동': [85, 80, 90, 95],
         '한사랑': [95, 90, 80, 90],
         '일지매': [90, 70, 60, 80]}

# %% [markdown]
# **3) 반복문 확장**
#
# - 앞에서 '리스트와 for 문'에서 다룬 내용과 동일하게 딕셔너리에 대해 사용할 수 있다.

# %%
score = {'홍길동': 85, '한사랑': 95, '일지매': 90}

score

# %%
# 90점 초과인 학생만 출력
score_over_90 = {key: value for key, value in score.items() if value > 90}
score_over_90

# %% [markdown]
# - 다음과 같은 코드로 같은 결과를 얻을 수 있다.

# %%
score_over_90 = {key : score[key] for key in score if score[key] > 90}
print(score_over_90)

# %% [markdown]
# ### 7.3.3.집합과 for 문
#
# - 리스트와 같은 방법으로 사용한다.

# %% [markdown]
# **1) 기본 반복문**
#
# - 리스트와 같은 방법으로 반복문에 사용한다.

# %%
member_set = {'홍길동',  '최나영', '이지수', '유재석'}

# %% [markdown]
# **2) enumerate() 함수 사용**

# %%
member_set = {'홍길동',  '최나영', '이지수', '유재석'}
