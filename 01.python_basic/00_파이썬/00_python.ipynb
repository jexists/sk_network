# %% [markdown]
# # UV

# %%
print("hello world")
# Out:
# hello world

# %%
0.1 + 0.2
# Out:
# 0.30000000000000004

# %%
print(0.1 + 0.2 == 0.3)

# 부등
# Out:
# False

# %%
test = [1,2,3]

test[:100000]
# Out:
# [1, 2, 3]

# %%
str = '12345'

print(str[0:2])
# Out:
# 12

# %%
# 문자열 슬라이싱
str = "12345"

# 리스트 슬라이싱
list = [1,2,3,4,5]

print(str[0:3])
print(list[0:3])
# Out:
# 123
# [1, 2, 3]

# %%
str = '에이' '비' '씨'

print(str)
# Out:
# gkkghehehoe

# %%
str = '에이', '비', '씨'
print(str)
# Out:
# ('에이', '비', '씨')

# %%
int = 1,2,3
print(int)
print(type(int))
# Out:
# (1, 2, 3)
# <class 'tuple'>
