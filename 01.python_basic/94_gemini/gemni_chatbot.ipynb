# %%
# 패키지 설치

# %pip install -q -U google-genai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from google import genai

# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client(api_key="GEMINI_API_KEY")


while True:
    user_input=input('나: ')
    if user_input.lower() in ['quit', 'exit']:
        print('챗봇을 종료합니다.')
        break

    response = client.models.generate_content(
        model="gemini-3-flash-preview", contents=user_input
    )
    print(response.text)
# Out:
# 안녕하세요! 반가워요. 무엇을 도와드릴까요? 무엇이든 궁금한 게 있다면 편하게 물어보세요!
# 네, 저 여기 있어요! 😊
#
# 그냥 불러주셔도 좋아요. 덕분에 저도 기분이 좋아지네요!
# 혹시 심심하시거나, 궁금한 게 생기면 언제든 말씀해 주세요. 아니면 그냥 시시콜콜한 이야기를 나눠도 좋고요!
#
# 지금 무슨 생각 하고 계셨나요?
# ---------------------------------------------------------------------------
# ServerError                               Traceback (most recent call last)
# Cell In[5], line 13
#      10     print('챗봇을 종료합니다.')
#      11     break
# ---> 13 response = client.models.generate_content(
#      14     model="gemini-3-flash-preview", contents=user_input
#      15 )
#      16 print(response.text)
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\models.py:6021, in Models.generate_content(self, model, contents, config)
#    6019 while remaining_remote_calls_afc > 0:
#    6020   i += 1
# -> 6021   response = self._generate_content(
#    6022       model=model, contents=contents, config=parsed_config
#    6023   )
#    6025   function_map = _extra_utils.get_function_map(parsed_config)
#    6026   if not function_map:
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\models.py:4683, in Models._generate_content(self, model, contents, config)
#    4680 request_dict = _common.convert_to_dict(request_dict)
#    4681 request_dict = _common.encode_unserializable_types(request_dict)
# -> 4683 response = self._api_client.request(
#    4684     'post', path, request_dict, http_options
#    4685 )
#    4687 if config is not None and getattr(
#    4688     config, 'should_return_http_response', None
#    4689 ):
#    4690   return_value = types.GenerateContentResponse(sdk_http_response=response)
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1532, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1522 def request(
#    1523     self,
#    1524     http_method: str,
#    (...)   1527     http_options: Optional[HttpOptionsOrDict] = None,
#    1528 ) -> SdkHttpResponse:
#    1529   http_request = self._build_request(
#    1530       http_method, path, request_dict, http_options
#    1531   )
# -> 1532   response = self._request(http_request, http_options, stream=False)
#    1533   response_body = (
#    1534       response.response_stream[0] if response.response_stream else ''
#    1535   )
#    1536   return SdkHttpResponse(headers=response.headers, body=response_body)
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1327, in BaseApiClient._request(self, http_request, http_options, stream)
#    1324     retry = tenacity.Retrying(**retry_kwargs)
#    1325     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1327 return self._retry(self._request_once, http_request, stream)
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     468 retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#     472         try:
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     369 result = None
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     411 retry_exc = self.retry_error_cls(fut)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     182 def reraise(self) -> t.NoReturn:
#     183     if self.last_attempt.failed:
# --> 184         raise self.last_attempt.result()
#     185     raise self
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:449, in Future.result(self, timeout)
#     447     raise CancelledError()
#     448 elif self._state == FINISHED:
# --> 449     return self.__get_result()
#     451 self._condition.wait(timeout)
#     453 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception is not None:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     471 if isinstance(do, DoAttempt):
#     472     try:
# --> 473         result = fn(*args, **kwargs)
#     474     except BaseException:  # noqa: B902
#     475         retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\_api_client.py:1304, in BaseApiClient._request_once(self, http_request, stream)
#    1296   httpx_request = self._httpx_client.build_request(  # type: ignore[union-attr]
#    1297       method=http_request.method,
#    1298       url=http_request.url,
#    (...)   1301       timeout=http_request.timeout,
#    1302   )
#    1303   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1304 errors.APIError.raise_for_response(response)
#    1305 return HttpResponse(
#    1306     response.headers, response if stream else [response.text]
#    1307 )
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     152 else:
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Users\playdata2\AppData\Local\Programs\Python\Python313\Lib\site-packages\google\genai\errors.py:186, in APIError.raise_error(cls, status_code, response_json, response)
#     184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
# --> 186   raise ServerError(status_code, response_json, response)
#     187 else:
#     188   raise cls(status_code, response_json, response)
#
# ServerError: 503 UNAVAILABLE. {'error': {'code': 503, 'message': 'This model is currently experiencing high demand. Spikes in demand are usually temporary. Please try again later.', 'status': 'UNAVAILABLE'}}
