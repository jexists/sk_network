# %% [markdown]
# # 1.공공 데이터 포털
#
# - 대한민국 정부가 제공하는 공공데이터 통합 플랫폼.
# - 공공기관이 생성 또는 취득하여 관리하고 있는 공공데이터를 한 곳에서 제공하는 통합 창구.
# - 손쉽게 공공데이터를 이용할 수 있도록 파일데이터, 오픈API, 시각화 등 다양한 방식으로 제공.
# - 누구라도 쉽고 편리한 검색을 통해 원하는 공공데이터를 빠르고 정확하게 찾을 수 있다.

# %% [markdown]
# - 우선 xml을 딕셔너리 형태로 변환하는 라이브러리 설치

# %%
# xmltodict 패키지 설치(아나콘다에는 이미 설치 됨)
# %pip install xmltodict

# %% [markdown]
# ## 1.1.관세청_국가별 수출입실적(GW)
#
# - 관세청 수출입통계정보의 기간, 국가, 국가코드, 수출건수,수출금액, 수입건수 등을 가져온다.

# %% [markdown]
# ### 1.1.1.데이터 가져오기

# %%
import json
import pandas as pd
import xmltodict
import urllib.request

# %%
from dotenv import load_dotenv
import os

load_dotenv()

key = os.getenv('data_key')

# %%
# 매게변수
strtYymm = 202501
endYymm = 202512
cntyCd = ''

# url 주소
url = f'https://apis.data.go.kr/1220000/nationtrade/getNationtradeList?serviceKey={key}&strtYymm={strtYymm}&endYymm={endYymm}&cntyCd={cntyCd}'

# %%
# 데이터 가져오기
response = urllib.request.urlopen(url)

print(response.status)
# Out:
# 200

# %%
# xml -> dict
xml_parse = xmltodict.parse(response) # XML 데이터를 딕셔너리로 파싱

xml_dict = json.loads(json.dumps(xml_parse)) # json 모듈을 활용해서 딕셔너리를 json 형식으로 변환

# print(xml_dict)

# %%
xml_dict
# Out:
# {'response': {'header': {'resultCode': '00', 'resultMsg': '정상서비스.'},
#   'body': {'items': {'item': [{'balPayments': '3443225952',
#       'expCnt': '193178',
#       'expDlr': '9282566788',
#       'impCnt': '1416582',
#       'impDlr': '5839340836',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'year': '2025.01'},
#      {'balPayments': '-2004621045',
#       'expCnt': '91388',
#       'expDlr': '9204172269',
#       'impCnt': '1225173',
#       'impDlr': '11208793314',
#       'statCd': 'CN',
#       'statCdCntnKor1': '중국',
#       'year': '2025.01'},
#      {'balPayments': '1792245180',
#       'expCnt': '57209',
#       'expDlr': '4356972160',
#       'impCnt': '145132',
#       'impDlr': '2564726980',
#       'statCd': 'VN',
#       'statCdCntnKor1': '베트남',
#       'year': '2025.01'},
#      {'balPayments': '210300569',
#       'expCnt': '34078',
#       'expDlr': '2438188048',
#       'impCnt': '20022',
#       'impDlr': '2227887479',
#       'statCd': 'TW',
#       'statCdCntnKor1': '대만',
#       'year': '2025.01'},
#      {'balPayments': '-1223548429',
#       'expCnt': '146929',
#       'expDlr': '2363796881',
#       'impCnt': '344783',
#       'impDlr': '3587345310',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'year': '2025.01'},
#      {'balPayments': '1502111293',
#       'expCnt': '18142',
#       'expDlr': '1685484400',
#       'impCnt': '145075',
#       'impDlr': '183373107',
#       'statCd': 'HK',
#       'statCdCntnKor1': '홍콩',
#       'year': '2025.01'},
#      {'balPayments': '928096823',
#       'expCnt': '18165',
#       'expDlr': '1463920945',
#       'impCnt': '10408',
#       'impDlr': '535824122',
#       'statCd': 'IN',
#       'statCdCntnKor1': '인도',
#       'year': '2025.01'},
#      {'balPayments': '134187136',
#       'expCnt': '42253',
#       'expDlr': '1162019513',
#       'impCnt': '18404',
#       'impDlr': '1027832377',
#       'statCd': 'SG',
#       'statCdCntnKor1': '싱가포르',
#       'year': '2025.01'},
#      {'balPayments': '179175548',
#       'expCnt': '15031',
#       'expDlr': '947164179',
#       'impCnt': '6035',
#       'impDlr': '767988631',
#       'statCd': 'MX',
#       'statCdCntnKor1': '멕시코',
#       'year': '2025.01'},
#      {'balPayments': '-429397344',
#       'expCnt': '26784',
#       'expDlr': '921581753',
#       'impCnt': '10823',
#       'impDlr': '1350979097',
#       'statCd': 'MY',
#       'statCdCntnKor1': '말레이시아',
#       'year': '2025.01'},
#      {'balPayments': '-1997255017',
#       'expCnt': '15080',
#       'expDlr': '909426750',
#       'impCnt': '46098',
#       'impDlr': '2906681767',
#       'statCd': 'AU',
#       'statCdCntnKor1': '호주',
#       'year': '2025.01'},
#      {'balPayments': '651665145',
#       'expCnt': '25805',
#       'expDlr': '880737363',
#       'impCnt': '5154',
#       'impDlr': '229072218',
#       'statCd': 'PH',
#       'statCdCntnKor1': '필리핀',
#       'year': '2025.01'},
#      {'balPayments': '-620017969',
#       'expCnt': '12862',
#       'expDlr': '769583494',
#       'impCnt': '182280',
#       'impDlr': '1389601463',
#       'statCd': 'DE',
#       'statCdCntnKor1': '독일',
#       'year': '2025.01'},
#      {'balPayments': '684513428',
#       'expCnt': '5877',
#       'expDlr': '765206162',
#       'impCnt': '2266',
#       'impDlr': '80692734',
#       'statCd': 'PL',
#       'statCdCntnKor1': '폴란드',
#       'year': '2025.01'},
#      {'balPayments': '737928915',
#       'expCnt': '26',
#       'expDlr': '737986093',
#       'impCnt': '19',
#       'impDlr': '57178',
#       'statCd': 'MH',
#       'statCdCntnKor1': '마샬군도',
#       'year': '2025.01'},
#      {'balPayments': '192078215',
#       'expCnt': '18111',
#       'expDlr': '734752287',
#       'impCnt': '35388',
#       'impDlr': '542674072',
#       'statCd': 'CA',
#       'statCdCntnKor1': '캐나다',
#       'year': '2025.01'},
#      {'balPayments': '554082782',
#       'expCnt': '14543',
#       'expDlr': '662302204',
#       'impCnt': '2556',
#       'impDlr': '108219422',
#       'statCd': 'TR',
#       'statCdCntnKor1': '튀르키예',
#       'year': '2025.01'},
#      {'balPayments': '163581432',
#       'expCnt': '17639',
#       'expDlr': '624224814',
#       'impCnt': '42817',
#       'impDlr': '460643382',
#       'statCd': 'TH',
#       'statCdCntnKor1': '태국',
#       'year': '2025.01'},
#      {'balPayments': '224066443',
#       'expCnt': '16092',
#       'expDlr': '556946982',
#       'impCnt': '29145',
#       'impDlr': '332880539',
#       'statCd': 'GB',
#       'statCdCntnKor1': '영국',
#       'year': '2025.01'},
#      {'balPayments': '-562973689',
#       'expCnt': '12319',
#       'expDlr': '551655213',
#       'impCnt': '8931',
#       'impDlr': '1114628902',
#       'statCd': 'ID',
#       'statCdCntnKor1': '인도네시아',
#       'year': '2025.01'},
#      {'balPayments': '-6266128',
#       'expCnt': '6309',
#       'expDlr': '476678490',
#       'impCnt': '19289',
#       'impDlr': '482944618',
#       'statCd': 'FR',
#       'statCdCntnKor1': '프랑스',
#       'year': '2025.01'},
#      {'balPayments': '-26294992',
#       'expCnt': '8910',
#       'expDlr': '458101813',
#       'impCnt': '5392',
#       'impDlr': '484396805',
#       'statCd': 'NL',
#       'statCdCntnKor1': '네덜란드',
#       'year': '2025.01'},
#      {'balPayments': '457783206',
#       'expCnt': '57',
#       'expDlr': '457792875',
#       'impCnt': '29',
#       'impDlr': '9669',
#       'statCd': 'LR',
#       'statCdCntnKor1': '라이베리아',
#       'year': '2025.01'},
#      {'balPayments': '-282366320',
#       'expCnt': '7368',
#       'expDlr': '405356891',
#       'impCnt': '1627',
#       'impDlr': '687723211',
#       'statCd': 'BR',
#       'statCdCntnKor1': '브라질',
#       'year': '2025.01'},
#      {'balPayments': '-124249619',
#       'expCnt': '5694',
#       'expDlr': '336927313',
#       'impCnt': '28493',
#       'impDlr': '461176932',
#       'statCd': 'IT',
#       'statCdCntnKor1': '이탈리아',
#       'year': '2025.01'},
#      {'balPayments': '-1127459172',
#       'expCnt': '8682',
#       'expDlr': '329442024',
#       'impCnt': '460',
#       'impDlr': '1456901196',
#       'statCd': 'AE',
#       'statCdCntnKor1': '아랍에미리트 연합',
#       'year': '2025.01'},
#      {'balPayments': '187935350',
#       'expCnt': '2372',
#       'expDlr': '312584293',
#       'impCnt': '2247',
#       'impDlr': '124648943',
#       'statCd': 'BE',
#       'statCdCntnKor1': '벨기에',
#       'year': '2025.01'},
#      {'balPayments': '-2190587907',
#       'expCnt': '3714',
#       'expDlr': '291910343',
#       'impCnt': '468',
#       'impDlr': '2482498250',
#       'statCd': 'SA',
#       'statCdCntnKor1': '사우디아라비아',
#       'year': '2025.01'},
#      {'balPayments': '202929035',
#       'expCnt': '2422',
#       'expDlr': '281161290',
#       'impCnt': '3582',
#       'impDlr': '78232255',
#       'statCd': 'CZ',
#       'statCdCntnKor1': '체코공화국',
#       'year': '2025.01'},
#      {'balPayments': '197989809',
#       'expCnt': '1825',
#       'expDlr': '254477023',
#       'impCnt': '1155',
#       'impDlr': '56487214',
#       'statCd': 'HU',
#       'statCdCntnKor1': '헝가리',
#       'year': '2025.01'},
#      {'balPayments': '115537352',
#       'expCnt': '1309',
#       'expDlr': '253412744',
#       'impCnt': '1756',
#       'impDlr': '137875392',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'year': '2025.01'},
#      {'balPayments': '16405506',
#       'expCnt': '3984',
#       'expDlr': '242347682',
#       'impCnt': '9360',
#       'impDlr': '225942176',
#       'statCd': 'ES',
#       'statCdCntnKor1': '스페인',
#       'year': '2025.01'},
#      {'balPayments': '-278687779',
#       'expCnt': '4709',
#       'expDlr': '223133772',
#       'impCnt': '1140',
#       'impDlr': '501821551',
#       'statCd': 'RU',
#       'statCdCntnKor1': '러시아 연방',
#       'year': '2025.01'},
#      {'balPayments': '181778535',
#       'expCnt': '3714',
#       'expDlr': '194103721',
#       'impCnt': '50',
#       'impDlr': '12325186',
#       'statCd': 'KZ',
#       'statCdCntnKor1': '카자흐스탄',
#       'year': '2025.01'},
#      {'balPayments': '164210666',
#       'expCnt': '195',
#       'expDlr': '181194201',
#       'impCnt': '116',
#       'impDlr': '16983535',
#       'statCd': 'MT',
#       'statCdCntnKor1': '몰타',
#       'year': '2025.01'},
#      {'balPayments': '38972537',
#       'expCnt': '3065',
#       'expDlr': '175268137',
#       'impCnt': '1508',
#       'impDlr': '136295600',
#       'statCd': 'IL',
#       'statCdCntnKor1': '이스라엘',
#       'year': '2025.01'},
#      {'balPayments': '115530846',
#       'expCnt': '1506',
#       'expDlr': '170924255',
#       'impCnt': '1136',
#       'impDlr': '55393409',
#       'statCd': 'SK',
#       'statCdCntnKor1': '슬로바키아',
#       'year': '2025.01'},
#      {'balPayments': '37203070',
#       'expCnt': '2848',
#       'expDlr': '139315474',
#       'impCnt': '31775',
#       'impDlr': '102112404',
#       'statCd': 'NZ',
#       'statCdCntnKor1': '뉴질랜드',
#       'year': '2025.01'},
#      {'balPayments': '-242289202',
#       'expCnt': '2119',
#       'expDlr': '123920256',
#       'impCnt': '1456',
#       'impDlr': '366209458',
#       'statCd': 'CL',
#       'statCdCntnKor1': '칠레',
#       'year': '2025.01'},
#      {'balPayments': '113257896',
#       'expCnt': '5567',
#       'expDlr': '114483826',
#       'impCnt': '11',
#       'impDlr': '1225930',
#       'statCd': 'KG',
#       'statCdCntnKor1': '키르기스스탄',
#       'year': '2025.01'},
#      {'balPayments': '113267176',
#       'expCnt': '40',
#       'expDlr': '113267669',
#       'impCnt': '1',
#       'impDlr': '493',
#       'statCd': 'BS',
#       'statCdCntnKor1': '바하마',
#       'year': '2025.01'},
#      {'balPayments': '108925454',
#       'expCnt': '1455',
#       'expDlr': '110091202',
#       'impCnt': '61',
#       'impDlr': '1165748',
#       'statCd': 'UZ',
#       'statCdCntnKor1': '우즈베키스탄',
#       'year': '2025.01'},
#      {'balPayments': '68914893',
#       'expCnt': '1484',
#       'expDlr': '107100732',
#       'impCnt': '571',
#       'impDlr': '38185839',
#       'statCd': 'PK',
#       'statCdCntnKor1': '파키스탄',
#       'year': '2025.01'},
#      {'balPayments': '-178871813',
#       'expCnt': '2147',
#       'expDlr': '101420663',
#       'impCnt': '3507',
#       'impDlr': '280292476',
#       'statCd': 'CH',
#       'statCdCntnKor1': '스위스',
#       'year': '2025.01'},
#      {'balPayments': '-692454901',
#       'expCnt': '733',
#       'expDlr': '99544684',
#       'impCnt': '80',
#       'impDlr': '791999585',
#       'statCd': 'IQ',
#       'statCdCntnKor1': '이라크',
#       'year': '2025.01'},
#      {'balPayments': '47008130',
#       'expCnt': '2319',
#       'expDlr': '99099948',
#       'impCnt': '1501',
#       'impDlr': '52091818',
#       'statCd': 'BD',
#       'statCdCntnKor1': '방글라데시',
#       'year': '2025.01'},
#      {'balPayments': '-59371249',
#       'expCnt': '1436',
#       'expDlr': '96082640',
#       'impCnt': '2789',
#       'impDlr': '155453889',
#       'statCd': 'SE',
#       'statCdCntnKor1': '스웨덴',
#       'year': '2025.01'},
#      {'balPayments': '85587284',
#       'expCnt': '2228',
#       'expDlr': '91577613',
#       'impCnt': '270',
#       'impDlr': '5990329',
#       'statCd': 'EG',
#       'statCdCntnKor1': '이집트',
#       'year': '2025.01'},
#      {'balPayments': '78289073',
#       'expCnt': '97',
#       'expDlr': '78319777',
#       'impCnt': '2',
#       'impDlr': '30704',
#       'statCd': 'AO',
#       'statCdCntnKor1': '앙골라',
#       'year': '2025.01'},
#      {'balPayments': '75017695',
#       'expCnt': '899',
#       'expDlr': '77923646',
#       'impCnt': '78',
#       'impDlr': '2905951',
#       'statCd': 'PA',
#       'statCdCntnKor1': '파나마',
#       'year': '2025.01'},
#      {'balPayments': '-30206160',
#       'expCnt': '914',
#       'expDlr': '76335641',
#       'impCnt': '975',
#       'impDlr': '106541801',
#       'statCd': 'IE',
#       'statCdCntnKor1': '아일랜드',
#       'year': '2025.01'},
#      {'balPayments': '-1341160952',
#       'expCnt': '908',
#       'expDlr': '73034059',
#       'impCnt': '200',
#       'impDlr': '1414195011',
#       'statCd': 'QA',
#       'statCdCntnKor1': '카타르',
#       'year': '2025.01'},
#      {'balPayments': '-29078604',
#       'expCnt': '1228',
#       'expDlr': '66485795',
#       'impCnt': '1158',
#       'impDlr': '95564399',
#       'statCd': 'CO',
#       'statCdCntnKor1': '콜롬비아',
#       'year': '2025.01'},
#      {'balPayments': '-434507048',
#       'expCnt': '993',
#       'expDlr': '65013103',
#       'impCnt': '60',
#       'impDlr': '499520151',
#       'statCd': 'OM',
#       'statCdCntnKor1': '오만',
#       'year': '2025.01'},
#      {'balPayments': '57423629',
#       'expCnt': '637',
#       'expDlr': '63883078',
#       'impCnt': '294',
#       'impDlr': '6459449',
#       'statCd': 'SI',
#       'statCdCntnKor1': '슬로베니아',
#       'year': '2025.01'},
#      {'balPayments': '-50904417',
#       'expCnt': '2179',
#       'expDlr': '62081514',
#       'impCnt': '1611',
#       'impDlr': '112985931',
#       'statCd': 'AT',
#       'statCdCntnKor1': '오스트리아',
#       'year': '2025.01'},
#      {'balPayments': '57810611',
#       'expCnt': '122',
#       'expDlr': '58354480',
#       'impCnt': '22',
#       'impDlr': '543869',
#       'statCd': 'PY',
#       'statCdCntnKor1': '파라과이',
#       'year': '2025.01'},
#      {'balPayments': '19665344',
#       'expCnt': '1011',
#       'expDlr': '56927732',
#       'impCnt': '4249',
#       'impDlr': '37262388',
#       'statCd': 'PT',
#       'statCdCntnKor1': '포루투갈',
#       'year': '2025.01'},
#      {'balPayments': '51030086',
#       'expCnt': '2013',
#       'expDlr': '55723382',
#       'impCnt': '100',
#       'impDlr': '4693296',
#       'statCd': 'JO',
#       'statCdCntnKor1': '요르단',
#       'year': '2025.01'},
#      {'balPayments': '7615156',
#       'expCnt': '1812',
#       'expDlr': '49598669',
#       'impCnt': '1020',
#       'impDlr': '41983513',
#       'statCd': 'KH',
#       'statCdCntnKor1': '캄보디아',
#       'year': '2025.01'},
#      {'balPayments': '-28983653',
#       'expCnt': '749',
#       'expDlr': '45115522',
#       'impCnt': '1038',
#       'impDlr': '74099175',
#       'statCd': 'FI',
#       'statCdCntnKor1': '핀란드',
#       'year': '2025.01'},
#      {'balPayments': '43008622',
#       'expCnt': '535',
#       'expDlr': '43488239',
#       'impCnt': '49',
#       'impDlr': '479617',
#       'statCd': 'GU',
#       'statCdCntnKor1': '괌',
#       'year': '2025.01'},
#      {'balPayments': '-6191048',
#       'expCnt': '1059',
#       'expDlr': '41323267',
#       'impCnt': '3403',
#       'impDlr': '47514315',
#       'statCd': 'RO',
#       'statCdCntnKor1': '루마니아',
#       'year': '2025.01'},
#      {'balPayments': '-38862218',
#       'expCnt': '851',
#       'expDlr': '41085566',
#       'impCnt': '54',
#       'impDlr': '79947784',
#       'statCd': 'NG',
#       'statCdCntnKor1': '나이지리아',
#       'year': '2025.01'},
#      {'balPayments': '-217157991',
#       'expCnt': '1146',
#       'expDlr': '40437898',
#       'impCnt': '791',
#       'impDlr': '257595889',
#       'statCd': 'PE',
#       'statCdCntnKor1': '페루',
#       'year': '2025.01'},
#      {'balPayments': '-223443714',
#       'expCnt': '1406',
#       'expDlr': '39934581',
#       'impCnt': '310',
#       'impDlr': '263378295',
#       'statCd': 'ZA',
#       'statCdCntnKor1': '남아프리카공화국',
#       'year': '2025.01'},
#      {'balPayments': '-766568709',
#       'expCnt': '699',
#       'expDlr': '35753099',
#       'impCnt': '64',
#       'impDlr': '802321808',
#       'statCd': 'KW',
#       'statCdCntnKor1': '쿠웨이트',
#       'year': '2025.01'},
#      {'balPayments': '-89320728',
#       'expCnt': '772',
#       'expDlr': '34938711',
#       'impCnt': '1928',
#       'impDlr': '124259439',
#       'statCd': 'NO',
#       'statCdCntnKor1': '노르웨이',
#       'year': '2025.01'},
#      {'balPayments': '23013568',
#       'expCnt': '364',
#       'expDlr': '34893762',
#       'impCnt': '116',
#       'impDlr': '11880194',
#       'statCd': 'PR',
#       'statCdCntnKor1': '푸에르토리코',
#       'year': '2025.01'},
#      {'balPayments': '1398927',
#       'expCnt': '775',
#       'expDlr': '33059806',
#       'impCnt': '167',
#       'impDlr': '31660879',
#       'statCd': 'UA',
#       'statCdCntnKor1': '우크라이나',
#       'year': '2025.01'},
#      {'balPayments': '30026549',
#       'expCnt': '9568',
#       'expDlr': '31688929',
#       'impCnt': '16',
#       'impDlr': '1662380',
#       'statCd': 'LY',
#       'statCdCntnKor1': '리비아',
#       'year': '2025.01'},
#      {'balPayments': '28968176',
#       'expCnt': '2280',
#       'expDlr': '31639167',
#       'impCnt': '1311',
#       'impDlr': '2670991',
#       'statCd': 'MN',
#       'statCdCntnKor1': '몽골',
#       'year': '2025.01'},
#      {'balPayments': '4868584',
#       'expCnt': '192',
#       'expDlr': '29884981',
#       'impCnt': '217',
#       'impDlr': '25016397',
#       'statCd': 'LA',
#       'statCdCntnKor1': '라오스',
#       'year': '2025.01'},
#      {'balPayments': '23072319',
#       'expCnt': '413',
#       'expDlr': '29687011',
#       'impCnt': '480',
#       'impDlr': '6614692',
#       'statCd': 'LT',
#       'statCdCntnKor1': '리투아니아',
#       'year': '2025.01'},
#      {'balPayments': '-66463918',
#       'expCnt': '994',
#       'expDlr': '27196412',
#       'impCnt': '382',
#       'impDlr': '93660330',
#       'statCd': 'GR',
#       'statCdCntnKor1': '그리스',
#       'year': '2025.01'},
#      {'balPayments': '-94682645',
#       'expCnt': '766',
#       'expDlr': '27035269',
#       'impCnt': '364',
#       'impDlr': '121717914',
#       'statCd': 'AR',
#       'statCdCntnKor1': '아르헨티나',
#       'year': '2025.01'},
#      {'balPayments': '-18552676',
#       'expCnt': '776',
#       'expDlr': '23365844',
#       'impCnt': '2256',
#       'impDlr': '41918520',
#       'statCd': 'MM',
#       'statCdCntnKor1': '미얀마',
#       'year': '2025.01'},
#      {'balPayments': '17643008',
#       'expCnt': '187',
#       'expDlr': '21022855',
#       'impCnt': '97',
#       'impDlr': '3379847',
#       'statCd': 'SV',
#       'statCdCntnKor1': '엘살바도르',
#       'year': '2025.01'},
#      {'balPayments': '7589727',
#       'expCnt': '376',
#       'expDlr': '20647032',
#       'impCnt': '360',
#       'impDlr': '13057305',
#       'statCd': 'MA',
#       'statCdCntnKor1': '모로코',
#       'year': '2025.01'},
#      {'balPayments': '8820066',
#       'expCnt': '363',
#       'expDlr': '20629980',
#       'impCnt': '207',
#       'impDlr': '11809914',
#       'statCd': 'EC',
#       'statCdCntnKor1': '에쿠아도르',
#       'year': '2025.01'},
#      {'balPayments': '-435176545',
#       'expCnt': '247',
#       'expDlr': '20215696',
#       'impCnt': '28',
#       'impDlr': '455392241',
#       'statCd': 'DZ',
#       'statCdCntnKor1': '알제리',
#       'year': '2025.01'},
#      {'balPayments': '10991759',
#       'expCnt': '729',
#       'expDlr': '18323773',
#       'impCnt': '182',
#       'impDlr': '7332014',
#       'statCd': 'GT',
#       'statCdCntnKor1': '과테말라',
#       'year': '2025.01'},
#      {'balPayments': '9423445',
#       'expCnt': '475',
#       'expDlr': '18160181',
#       'impCnt': '122',
#       'impDlr': '8736736',
#       'statCd': 'DO',
#       'statCdCntnKor1': '도미니카 공화국',
#       'year': '2025.01'},
#      {'balPayments': '10625624',
#       'expCnt': '746',
#       'expDlr': '17112799',
#       'impCnt': '22',
#       'impDlr': '6487175',
#       'statCd': 'GH',
#       'statCdCntnKor1': '가나',
#       'year': '2025.01'},
#      {'balPayments': '6817335',
#       'expCnt': '700',
#       'expDlr': '16795993',
#       'impCnt': '461',
#       'impDlr': '9978658',
#       'statCd': 'LK',
#       'statCdCntnKor1': '스리랑카',
#       'year': '2025.01'},
#      {'balPayments': '15873345',
#       'expCnt': '2307',
#       'expDlr': '15873345',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'TJ',
#       'statCdCntnKor1': '타지크',
#       'year': '2025.01'},
#      {'balPayments': '14045408',
#       'expCnt': '1112',
#       'expDlr': '14910996',
#       'impCnt': '79',
#       'impDlr': '865588',
#       'statCd': 'AL',
#       'statCdCntnKor1': '알바니아',
#       'year': '2025.01'},
#      {'balPayments': '4348288',
#       'expCnt': '856',
#       'expDlr': '13469713',
#       'impCnt': '363',
#       'impDlr': '9121425',
#       'statCd': 'CR',
#       'statCdCntnKor1': '코스타리카',
#       'year': '2025.01'},
#      {'balPayments': '-12843206',
#       'expCnt': '458',
#       'expDlr': '12897979',
#       'impCnt': '842',
#       'impDlr': '25741185',
#       'statCd': 'BG',
#       'statCdCntnKor1': '불가리아',
#       'year': '2025.01'},
#      {'balPayments': '10744398',
#       'expCnt': '23',
#       'expDlr': '12106161',
#       'impCnt': '15',
#       'impDlr': '1361763',
#       'statCd': 'SL',
#       'statCdCntnKor1': '시에라 리온',
#       'year': '2025.01'},
#      {'balPayments': '9771645',
#       'expCnt': '373',
#       'expDlr': '11511870',
#       'impCnt': '74',
#       'impDlr': '1740225',
#       'statCd': 'HN',
#       'statCdCntnKor1': '온두라스',
#       'year': '2025.01'},
#      {'balPayments': '3226289',
#       'expCnt': '302',
#       'expDlr': '11466446',
#       'impCnt': '31',
#       'impDlr': '8240157',
#       'statCd': 'TZ',
#       'statCdCntnKor1': '탄자니아',
#       'year': '2025.01'},
#      {'balPayments': '10645584',
#       'expCnt': '577',
#       'expDlr': '11039680',
#       'impCnt': '8',
#       'impDlr': '394096',
#       'statCd': 'AZ',
#       'statCdCntnKor1': '아제르바이잔',
#       'year': '2025.01'},
#      {'balPayments': '7215799',
#       'expCnt': '281',
#       'expDlr': '10638341',
#       'impCnt': '68',
#       'impDlr': '3422542',
#       'statCd': 'KE',
#       'statCdCntnKor1': '케냐',
#       'year': '2025.01'},
#      {'balPayments': '-6847922',
#       'expCnt': '134',
#       'expDlr': '10506655',
#       'impCnt': '33',
#       'impDlr': '17354577',
#       'statCd': 'CI',
#       'statCdCntnKor1': '코트디봐르',
#       'year': '2025.01'},
#      {'balPayments': '2376618',
#       'expCnt': '244',
#       'expDlr': '10497990',
#       'impCnt': '150',
#       'impDlr': '8121372',
#       'statCd': 'RS',
#       'statCdCntnKor1': '세르비아',
#       'year': '2025.01'},
#      {'balPayments': '-10034417',
#       'expCnt': '151',
#       'expDlr': '10208189',
#       'impCnt': '61',
#       'impDlr': '20242606',
#       'statCd': 'UY',
#       'statCdCntnKor1': '우루과이',
#       'year': '2025.01'},
#      {'balPayments': '9267950',
#       'expCnt': '434',
#       'expDlr': '9882905',
#       'impCnt': '102',
#       'impDlr': '614955',
#       'statCd': 'GE',
#       'statCdCntnKor1': '조지아',
#       'year': '2025.01'},
#      {'balPayments': '1987353',
#       'expCnt': '143',
#       'expDlr': '9342246',
#       'impCnt': '587',
#       'impDlr': '7354893',
#       'statCd': 'TN',
#       'statCdCntnKor1': '튀니지',
#       'year': '2025.01'},
#      {'balPayments': '8604504',
#       'expCnt': '194',
#       'expDlr': '8821420',
#       'impCnt': '12',
#       'impDlr': '216916',
#       'statCd': 'IR',
#       'statCdCntnKor1': '이란',
#       'year': '2025.01'},
#      {'balPayments': '1058647',
#       'expCnt': '64',
#       'expDlr': '8576826',
#       'impCnt': '262',
#       'impDlr': '7518179',
#       'statCd': 'ET',
#       'statCdCntnKor1': '에티오피아',
#       'year': '2025.01'},
#      {'balPayments': '-19967919',
#       'expCnt': '84',
#       'expDlr': '8412290',
#       'impCnt': '679',
#       'impDlr': '28380209',
#       'statCd': 'ZZ',
#       'statCdCntnKor1': '기타국',
#       'year': '2025.01'},
#      {'balPayments': '6817336',
#       'expCnt': '186',
#       'expDlr': '8313154',
#       'impCnt': '122',
#       'impDlr': '1495818',
#       'statCd': 'HR',
#       'statCdCntnKor1': '크로아티아',
#       'year': '2025.01'},
#      {'balPayments': '8198478',
#       'expCnt': '51',
#       'expDlr': '8239363',
#       'impCnt': '1',
#       'impDlr': '40885',
#       'statCd': 'DJ',
#       'statCdCntnKor1': '지부티',
#       'year': '2025.01'},
#      {'balPayments': '8048694',
#       'expCnt': '15',
#       'expDlr': '8048919',
#       'impCnt': '0',
#       'impDlr': '225',
#       'statCd': 'TM',
#       'statCdCntnKor1': '투르크멘',
#       'year': '2025.01'},
#      {'balPayments': '189443',
#       'expCnt': '285',
#       'expDlr': '7672612',
#       'impCnt': '263',
#       'impDlr': '7483169',
#       'statCd': 'EE',
#       'statCdCntnKor1': '에스토니아',
#       'year': '2025.01'},
#      {'balPayments': '5222234',
#       'expCnt': '134',
#       'expDlr': '7582455',
#       'impCnt': '13',
#       'impDlr': '2360221',
#       'statCd': 'BN',
#       'statCdCntnKor1': '브루나이',
#       'year': '2025.01'},
#      {'balPayments': '5141097',
#       'expCnt': '186',
#       'expDlr': '6331708',
#       'impCnt': '46',
#       'impDlr': '1190611',
#       'statCd': 'LB',
#       'statCdCntnKor1': '레바논',
#       'year': '2025.01'},
#      {'balPayments': '-145240016',
#       'expCnt': '77',
#       'expDlr': '6289946',
#       'impCnt': '28',
#       'impDlr': '151529962',
#       'statCd': 'PG',
#       'statCdCntnKor1': '파푸아 뉴기니',
#       'year': '2025.01'},
#      {'balPayments': '3033583',
#       'expCnt': '440',
#       'expDlr': '6057593',
#       'impCnt': '41',
#       'impDlr': '3024010',
#       'statCd': 'SN',
#       'statCdCntnKor1': '세네갈',
#       'year': '2025.01'},
#      {'balPayments': '592458',
#       'expCnt': '140',
#       'expDlr': '5795514',
#       'impCnt': '292',
#       'impDlr': '5203056',
#       'statCd': 'MD',
#       'statCdCntnKor1': '몰도바',
#       'year': '2025.01'},
#      {'balPayments': '-32085562',
#       'expCnt': '54',
#       'expDlr': '5667394',
#       'impCnt': '15',
#       'impDlr': '37752956',
#       'statCd': 'MZ',
#       'statCdCntnKor1': '모잠비크',
#       'year': '2025.01'},
#      {'balPayments': '5434434',
#       'expCnt': '30',
#       'expDlr': '5434438',
#       'impCnt': '0',
#       'impDlr': '4',
#       'statCd': 'SD',
#       'statCdCntnKor1': '수단',
#       'year': '2025.01'},
#      {'balPayments': '-68213153',
#       'expCnt': '244',
#       'expDlr': '5241635',
#       'impCnt': '69',
#       'impDlr': '73454788',
#       'statCd': 'BH',
#       'statCdCntnKor1': '바레인',
#       'year': '2025.01'},
#      {'balPayments': '4498742',
#       'expCnt': '89',
#       'expDlr': '4547326',
#       'impCnt': '3',
#       'impDlr': '48584',
#       'statCd': 'GY',
#       'statCdCntnKor1': '가이아나',
#       'year': '2025.01'},
#      {'balPayments': '-9279101',
#       'expCnt': '70',
#       'expDlr': '4260668',
#       'impCnt': '42',
#       'impDlr': '13539769',
#       'statCd': 'TT',
#       'statCdCntnKor1': '트리니다드 토바고',
#       'year': '2025.01'},
#      {'balPayments': '3329709',
#       'expCnt': '155',
#       'expDlr': '4245481',
#       'impCnt': '19',
#       'impDlr': '915772',
#       'statCd': 'BY',
#       'statCdCntnKor1': '벨라루스',
#       'year': '2025.01'},
#      {'balPayments': '-5220589',
#       'expCnt': '201',
#       'expDlr': '4146123',
#       'impCnt': '302',
#       'impDlr': '9366712',
#       'statCd': 'LV',
#       'statCdCntnKor1': '라트비아',
#       'year': '2025.01'},
#      {'balPayments': '2877953',
#       'expCnt': '126',
#       'expDlr': '4109352',
#       'impCnt': '31',
#       'impDlr': '1231399',
#       'statCd': 'NI',
#       'statCdCntnKor1': '니카라과',
#       'year': '2025.01'},
#      {'balPayments': '3248197',
#       'expCnt': '120',
#       'expDlr': '4080380',
#       'impCnt': '39',
#       'impDlr': '832183',
#       'statCd': 'IS',
#       'statCdCntnKor1': '아이슬란드',
#       'year': '2025.01'},
#      {'balPayments': '-6328264',
#       'expCnt': '155',
#       'expDlr': '3797888',
#       'impCnt': '202',
#       'impDlr': '10126152',
#       'statCd': 'LU',
#       'statCdCntnKor1': '룩셈부르그',
#       'year': '2025.01'},
#      {'balPayments': '3370274',
#       'expCnt': '13',
#       'expDlr': '3370274',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'WS',
#       'statCdCntnKor1': '사모아',
#       'year': '2025.01'},
#      {'balPayments': '2753566',
#       'expCnt': '81',
#       'expDlr': '3367276',
#       'impCnt': '3',
#       'impDlr': '613710',
#       'statCd': 'CG',
#       'statCdCntnKor1': '콩고',
#       'year': '2025.01'},
#      {'balPayments': '3048927',
#       'expCnt': '120',
#       'expDlr': '3236658',
#       'impCnt': '15',
#       'impDlr': '187731',
#       'statCd': 'MU',
#       'statCdCntnKor1': '모리셔스',
#       'year': '2025.01'},
#      {'balPayments': '3218413',
#       'expCnt': '7',
#       'expDlr': '3218520',
#       'impCnt': '0',
#       'impDlr': '107',
#       'statCd': 'SS',
#       'statCdCntnKor1': '남수단',
#       'year': '2025.01'},
#      {'balPayments': '-3303662',
#       'expCnt': '280',
#       'expDlr': '3125394',
#       'impCnt': '41',
#       'impDlr': '6429056',
#       'statCd': 'YE',
#       'statCdCntnKor1': '예맨',
#       'year': '2025.01'},
#      {'balPayments': '2836702',
#       'expCnt': '80',
#       'expDlr': '2996571',
#       'impCnt': '15',
#       'impDlr': '159869',
#       'statCd': 'FJ',
#       'statCdCntnKor1': '피지',
#       'year': '2025.01'},
#      {'balPayments': '-1017283',
#       'expCnt': '264',
#       'expDlr': '2955140',
#       'impCnt': '36',
#       'impDlr': '3972423',
#       'statCd': 'GN',
#       'statCdCntnKor1': '기니',
#       'year': '2025.01'},
#      {'balPayments': '2764232',
#       'expCnt': '58',
#       'expDlr': '2841178',
#       'impCnt': '8',
#       'impDlr': '76946',
#       'statCd': 'JM',
#       'statCdCntnKor1': '자마이카',
#       'year': '2025.01'},
#      {'balPayments': '1465607',
#       'expCnt': '217',
#       'expDlr': '2699574',
#       'impCnt': '33',
#       'impDlr': '1233967',
#       'statCd': 'CY',
#       'statCdCntnKor1': '사이프러스',
#       'year': '2025.01'},
#      {'balPayments': '2198861',
#       'expCnt': '70',
#       'expDlr': '2638295',
#       'impCnt': '6',
#       'impDlr': '439434',
#       'statCd': 'VE',
#       'statCdCntnKor1': '베네주엘라',
#       'year': '2025.01'},
#      {'balPayments': '2509851',
#       'expCnt': '40',
#       'expDlr': '2509851',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'RE',
#       'statCdCntnKor1': '불령 리유니온 코모도 제도',
#       'year': '2025.01'},
#      {'balPayments': '-69344052',
#       'expCnt': '69',
#       'expDlr': '2489683',
#       'impCnt': '12',
#       'impDlr': '71833735',
#       'statCd': 'BO',
#       'statCdCntnKor1': '볼리비아',
#       'year': '2025.01'},
#      {'balPayments': '2329094',
#       'expCnt': '77',
#       'expDlr': '2427495',
#       'impCnt': '10',
#       'impDlr': '98401',
#       'statCd': 'AF',
#       'statCdCntnKor1': '아프카니스탄',
#       'year': '2025.01'},
#      {'balPayments': '2037160',
#       'expCnt': '203',
#       'expDlr': '2043262',
#       'impCnt': '1',
#       'impDlr': '6102',
#       'statCd': 'SY',
#       'statCdCntnKor1': '시리아',
#       'year': '2025.01'},
#      {'balPayments': '2027227',
#       'expCnt': '50',
#       'expDlr': '2027227',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'AW',
#       'statCdCntnKor1': '아루바',
#       'year': '2025.01'},
#      {'balPayments': '1410329',
#       'expCnt': '212',
#       'expDlr': '1974005',
#       'impCnt': '86',
#       'impDlr': '563676',
#       'statCd': 'NP',
#       'statCdCntnKor1': '네팔',
#       'year': '2025.01'},
#      {'balPayments': '-4461579',
#       'expCnt': '183',
#       'expDlr': '1797690',
#       'impCnt': '123',
#       'impDlr': '6259269',
#       'statCd': 'MG',
#       'statCdCntnKor1': '마다카스카르',
#       'year': '2025.01'},
#      {'balPayments': '1763587',
#       'expCnt': '23',
#       'expDlr': '1769183',
#       'impCnt': '1',
#       'impDlr': '5596',
#       'statCd': 'MQ',
#       'statCdCntnKor1': '마티니크',
#       'year': '2025.01'},
#      {'balPayments': '1763130',
#       'expCnt': '10',
#       'expDlr': '1763130',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'BZ',
#       'statCdCntnKor1': '벨리제',
#       'year': '2025.01'},
#      {'balPayments': '885385',
#       'expCnt': '81',
#       'expDlr': '1735501',
#       'impCnt': '13',
#       'impDlr': '850116',
#       'statCd': 'TG',
#       'statCdCntnKor1': '토고',
#       'year': '2025.01'},
#      {'balPayments': '1169666',
#       'expCnt': '93',
#       'expDlr': '1651009',
#       'impCnt': '12',
#       'impDlr': '481343',
#       'statCd': 'CM',
#       'statCdCntnKor1': '카메룬',
#       'year': '2025.01'},
#      {'balPayments': '1536002',
#       'expCnt': '26',
#       'expDlr': '1573205',
#       'impCnt': '1',
#       'impDlr': '37203',
#       'statCd': 'BJ',
#       'statCdCntnKor1': '베닝',
#       'year': '2025.01'},
#      {'balPayments': '1280351',
#       'expCnt': '182',
#       'expDlr': '1559797',
#       'impCnt': '9',
#       'impDlr': '279446',
#       'statCd': 'RW',
#       'statCdCntnKor1': '르완다',
#       'year': '2025.01'},
#      {'balPayments': '1507596',
#       'expCnt': '3',
#       'expDlr': '1513439',
#       'impCnt': '2',
#       'impDlr': '5843',
#       'statCd': 'NE',
#       'statCdCntnKor1': '니제르',
#       'year': '2025.01'},
#      {'balPayments': '1416172',
#       'expCnt': '11',
#       'expDlr': '1472226',
#       'impCnt': '1',
#       'impDlr': '56054',
#       'statCd': 'BF',
#       'statCdCntnKor1': '부르키나 파소',
#       'year': '2025.01'},
#      {'balPayments': '1303487',
#       'expCnt': '278',
#       'expDlr': '1382028',
#       'impCnt': '1',
#       'impDlr': '78541',
#       'statCd': 'GA',
#       'statCdCntnKor1': '가봉',
#       'year': '2025.01'},
#      {'balPayments': '-3481233',
#       'expCnt': '64',
#       'expDlr': '1310088',
#       'impCnt': '232',
#       'impDlr': '4791321',
#       'statCd': 'AM',
#       'statCdCntnKor1': '아르메니아',
#       'year': '2025.01'},
#      {'balPayments': '1271220',
#       'expCnt': '22',
#       'expDlr': '1272981',
#       'impCnt': '3',
#       'impDlr': '1761',
#       'statCd': 'HT',
#       'statCdCntnKor1': '아이티',
#       'year': '2025.01'},
#      {'balPayments': '-3272980',
#       'expCnt': '52',
#       'expDlr': '1168280',
#       'impCnt': '2',
#       'impDlr': '4441260',
#       'statCd': 'ZM',
#       'statCdCntnKor1': '잠비아',
#       'year': '2025.01'},
#      {'balPayments': '1118948',
#       'expCnt': '148',
#       'expDlr': '1145046',
#       'impCnt': '2',
#       'impDlr': '26098',
#       'statCd': 'MP',
#       'statCdCntnKor1': '북마리아나 군도',
#       'year': '2025.01'},
#      {'balPayments': '938073',
#       'expCnt': '45',
#       'expDlr': '1098225',
#       'impCnt': '4',
#       'impDlr': '160152',
#       'statCd': 'PF',
#       'statCdCntnKor1': '불령 폴리네시아',
#       'year': '2025.01'},
#      {'balPayments': '383492',
#       'expCnt': '20',
#       'expDlr': '1056132',
#       'impCnt': '8',
#       'impDlr': '672640',
#       'statCd': 'ZW',
#       'statCdCntnKor1': '짐바브웨',
#       'year': '2025.01'},
#      {'balPayments': '680166',
#       'expCnt': '26',
#       'expDlr': '1054358',
#       'impCnt': '3',
#       'impDlr': '374192',
#       'statCd': 'SO',
#       'statCdCntnKor1': '소말리아',
#       'year': '2025.01'},
#      {'balPayments': '942714',
#       'expCnt': '12',
#       'expDlr': '1046520',
#       'impCnt': '3',
#       'impDlr': '103806',
#       'statCd': 'ML',
#       'statCdCntnKor1': '말리',
#       'year': '2025.01'},
#      {'balPayments': '-86096561',
#       'expCnt': '21',
#       'expDlr': '1037382',
#       'impCnt': '44',
#       'impDlr': '87133943',
#       'statCd': 'CD',
#       'statCdCntnKor1': '콩고민주공화국',
#       'year': '2025.01'},
#      {'balPayments': '1007189',
#       'expCnt': '43',
#       'expDlr': '1025609',
#       'impCnt': '1',
#       'impDlr': '18420',
#       'statCd': 'CW',
#       'statCdCntnKor1': '큐라소',
#       'year': '2025.01'},
#      {'balPayments': '1005869',
#       'expCnt': '14',
#       'expDlr': '1005869',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'MF',
#       'statCdCntnKor1': '세인트 마틴',
#       'year': '2025.01'},
#      {'balPayments': '1005741',
#       'expCnt': '15',
#       'expDlr': '1005741',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'GP',
#       'statCdCntnKor1': '과델로프',
#       'year': '2025.01'},
#      {'balPayments': '918079',
#       'expCnt': '8',
#       'expDlr': '918079',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'PS',
#       'statCdCntnKor1': '팔레스타인 해방기구',
#       'year': '2025.01'},
#      {'balPayments': '136960',
#       'expCnt': '22',
#       'expDlr': '913833',
#       'impCnt': '12',
#       'impDlr': '776873',
#       'statCd': 'SR',
#       'statCdCntnKor1': '수리남',
#       'year': '2025.01'},
#      {'balPayments': '774091',
#       'expCnt': '172',
#       'expDlr': '867392',
#       'impCnt': '28',
#       'impDlr': '93301',
#       'statCd': 'MO',
#       'statCdCntnKor1': '마카오',
#       'year': '2025.01'},
#      {'balPayments': '783917',
#       'expCnt': '10',
#       'expDlr': '784597',
#       'impCnt': '2',
#       'impDlr': '680',
#       'statCd': 'BM',
#       'statCdCntnKor1': '버뮤다',
#       'year': '2025.01'},
#      {'balPayments': '675693',
#       'expCnt': '50',
#       'expDlr': '704851',
#       'impCnt': '2',
#       'impDlr': '29158',
#       'statCd': 'FM',
#       'statCdCntnKor1': '마이크로네시아',
#       'year': '2025.01'},
#      {'balPayments': '24281',
#       'expCnt': '35',
#       'expDlr': '649492',
#       'impCnt': '7',
#       'impDlr': '625211',
#       'statCd': 'VU',
#       'statCdCntnKor1': '바누아투',
#       'year': '2025.01'},
#      {'balPayments': '-140041',
#       'expCnt': '33',
#       'expDlr': '623073',
#       'impCnt': '20',
#       'impDlr': '763114',
#       'statCd': 'UG',
#       'statCdCntnKor1': '우간다',
#       'year': '2025.01'},
#      {'balPayments': '608163',
#       'expCnt': '6',
#       'expDlr': '610241',
#       'impCnt': '1',
#       'impDlr': '2078',
#       'statCd': 'TV',
#       'statCdCntnKor1': '투발루',
#       'year': '2025.01'},
#      {'balPayments': '604857',
#       'expCnt': '15',
#       'expDlr': '604874',
#       'impCnt': '1',
#       'impDlr': '17',
#       'statCd': 'SB',
#       'statCdCntnKor1': '솔로몬 군도',
#       'year': '2025.01'},
#      {'balPayments': '572275',
#       'expCnt': '16',
#       'expDlr': '596642',
#       'impCnt': '2',
#       'impDlr': '24367',
#       'statCd': 'PW',
#       'statCdCntnKor1': '팔라우',
#       'year': '2025.01'},
#      {'balPayments': '594136',
#       'expCnt': '7',
#       'expDlr': '594150',
#       'impCnt': '0',
#       'impDlr': '14',
#       'statCd': 'BI',
#       'statCdCntnKor1': '부룬디',
#       'year': '2025.01'},
#      {'balPayments': '-989753',
#       'expCnt': '37',
#       'expDlr': '590179',
#       'impCnt': '5',
#       'impDlr': '1579932',
#       'statCd': 'BT',
#       'statCdCntnKor1': '부탄',
#       'year': '2025.01'},
#      {'balPayments': '537616',
#       'expCnt': '46',
#       'expDlr': '537616',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'KI',
#       'statCdCntnKor1': '키리바티',
#       'year': '2025.01'},
#      {'balPayments': '-434515',
#       'expCnt': '14',
#       'expDlr': '527820',
#       'impCnt': '44',
#       'impDlr': '962335',
#       'statCd': 'LI',
#       'statCdCntnKor1': '리히텐슈타인',
#       'year': '2025.01'},
#      {'balPayments': '451895',
#       'expCnt': '11',
#       'expDlr': '503244',
#       'impCnt': '4',
#       'impDlr': '51349',
#       'statCd': 'BW',
#       'statCdCntnKor1': '보츠와나',
#       'year': '2025.01'},
#      {'balPayments': '477557',
#       'expCnt': '7',
#       'expDlr': '479940',
#       'impCnt': '4',
#       'impDlr': '2383',
#       'statCd': 'ME',
#       'statCdCntnKor1': '몬테네그로',
#       'year': '2025.01'},
#      {'balPayments': '-1041008',
#       'expCnt': '39',
#       'expDlr': '461957',
#       'impCnt': '10',
#       'impDlr': '1502965',
#       'statCd': 'MR',
#       'statCdCntnKor1': '모리타니',
#       'year': '2025.01'},
#      {'balPayments': '-2361717',
#       'expCnt': '43',
#       'expDlr': '461052',
#       'impCnt': '61',
#       'impDlr': '2822769',
#       'statCd': 'BA',
#       'statCdCntnKor1': '보스니아-헤르체고비나',
#       'year': '2025.01'},
#      {'balPayments': '340592',
#       'expCnt': '17',
#       'expDlr': '424095',
#       'impCnt': '9',
#       'impDlr': '83503',
#       'statCd': 'BB',
#       'statCdCntnKor1': '바베이도스',
#       'year': '2025.01'},
#      {'balPayments': '409952',
#       'expCnt': '77',
#       'expDlr': '411643',
#       'impCnt': '2',
#       'impDlr': '1691',
#       'statCd': 'MV',
#       'statCdCntnKor1': '몰디브',
#       'year': '2025.01'},
#      {'balPayments': '243349',
#       'expCnt': '10',
#       'expDlr': '395190',
#       'impCnt': '2',
#       'impDlr': '151841',
#       'statCd': 'AS',
#       'statCdCntnKor1': '아메리칸 사모아',
#       'year': '2025.01'},
#      {'balPayments': '365836',
#       'expCnt': '5',
#       'expDlr': '366571',
#       'impCnt': '1',
#       'impDlr': '735',
#       'statCd': 'GD',
#       'statCdCntnKor1': '그레나다',
#       'year': '2025.01'},
#      {'balPayments': '316587',
#       'expCnt': '4',
#       'expDlr': '316669',
#       'impCnt': '0',
#       'impDlr': '82',
#       'statCd': 'CV',
#       'statCdCntnKor1': '카보 베르데',
#       'year': '2025.01'},
#      {'balPayments': '231627',
#       'expCnt': '22',
#       'expDlr': '298322',
#       'impCnt': '3',
#       'impDlr': '66695',
#       'statCd': 'NA',
#       'statCdCntnKor1': '나미비아',
#       'year': '2025.01'},
#      {'balPayments': '275362',
#       'expCnt': '8',
#       'expDlr': '275362',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'LC',
#       'statCdCntnKor1': '세인트 루시아',
#       'year': '2025.01'},
#      {'balPayments': '275187',
#       'expCnt': '7',
#       'expDlr': '275187',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'AG',
#       'statCdCntnKor1': '안티가 바부다',
#       'year': '2025.01'},
#      {'balPayments': '-619414',
#       'expCnt': '74',
#       'expDlr': '257178',
#       'impCnt': '13',
#       'impDlr': '876592',
#       'statCd': 'GM',
#       'statCdCntnKor1': '감비아',
#       'year': '2025.01'},
#      {'balPayments': '-603280',
#       'expCnt': '39',
#       'expDlr': '241773',
#       'impCnt': '17',
#       'impDlr': '845053',
#       'statCd': 'MK',
#       'statCdCntnKor1': '마세도니아',
#       'year': '2025.01'},
#      {'balPayments': '240809',
#       'expCnt': '12',
#       'expDlr': '240809',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'KY',
#       'statCdCntnKor1': '영령 캐이맨 군도',
#       'year': '2025.01'},
#      {'balPayments': '155276',
#       'expCnt': '10',
#       'expDlr': '236782',
#       'impCnt': '1',
#       'impDlr': '81506',
#       'statCd': 'GQ',
#       'statCdCntnKor1': '적도 기니',
#       'year': '2025.01'},
#      {'balPayments': '-698792',
#       'expCnt': '15',
#       'expDlr': '229399',
#       'impCnt': '5',
#       'impDlr': '928191',
#       'statCd': 'CU',
#       'statCdCntnKor1': '쿠바',
#       'year': '2025.01'},
#      {'balPayments': '-19865559',
#       'expCnt': '35',
#       'expDlr': '181643',
#       'impCnt': '9',
#       'impDlr': '20047202',
#       'statCd': 'NC',
#       'statCdCntnKor1': '뉴 칼레도니아',
#       'year': '2025.01'},
#      {'balPayments': '171448',
#       'expCnt': '9',
#       'expDlr': '171448',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'GF',
#       'statCdCntnKor1': '불령 가이아나',
#       'year': '2025.01'},
#      {'balPayments': '162401',
#       'expCnt': '2',
#       'expDlr': '162401',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'VG',
#       'statCdCntnKor1': '영령 버진군도',
#       'year': '2025.01'},
#      {'balPayments': '-40870',
#       'expCnt': '16',
#       'expDlr': '162149',
#       'impCnt': '6',
#       'impDlr': '203019',
#       'statCd': 'SC',
#       'statCdCntnKor1': '세이쉘',
#       'year': '2025.01'},
#      {'balPayments': '152943',
#       'expCnt': '3',
#       'expDlr': '152943',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'VC',
#       'statCdCntnKor1': '세인트 빈센트 그레나딘',
#       'year': '2025.01'},
#      {'balPayments': '98716',
#       'expCnt': '8',
#       'expDlr': '150628',
#       'impCnt': '14',
#       'impDlr': '51912',
#       'statCd': 'SZ',
#       'statCdCntnKor1': '스와질랜드',
#       'year': '2025.01'},
#      {'balPayments': '105542',
#       'expCnt': '4',
#       'expDlr': '123810',
#       'impCnt': '3',
#       'impDlr': '18268',
#       'statCd': 'DM',
#       'statCdCntnKor1': '도미니카',
#       'year': '2025.01'},
#      {'balPayments': '108139',
#       'expCnt': '7',
#       'expDlr': '108139',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'TC',
#       'statCdCntnKor1': '투르크 & 카이코스 군도',
#       'year': '2025.01'},
#      {'balPayments': '89413',
#       'expCnt': '1',
#       'expDlr': '89413',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'YT',
#       'statCdCntnKor1': '메요트',
#       'year': '2025.01'},
#      {'balPayments': '-76594',
#       'expCnt': '3',
#       'expDlr': '72617',
#       'impCnt': '5',
#       'impDlr': '149211',
#       'statCd': 'GW',
#       'statCdCntnKor1': '기네비소',
#       'year': '2025.01'},
#      {'balPayments': '-1480736',
#       'expCnt': '7',
#       'expDlr': '68980',
#       'impCnt': '9',
#       'impDlr': '1549716',
#       'statCd': 'MW',
#       'statCdCntnKor1': '말라위',
#       'year': '2025.01'},
#      {'balPayments': '59579',
#       'expCnt': '2',
#       'expDlr': '60178',
#       'impCnt': '2',
#       'impDlr': '599',
#       'statCd': 'KN',
#       'statCdCntnKor1': '세인트 키츠 네비스',
#       'year': '2025.01'},
#      {'balPayments': '25308',
#       'expCnt': '4',
#       'expDlr': '27765',
#       'impCnt': '4',
#       'impDlr': '2457',
#       'statCd': 'TL',
#       'statCdCntnKor1': '티모르',
#       'year': '2025.01'},
#      {'balPayments': '26930',
#       'expCnt': '7',
#       'expDlr': '26982',
#       'impCnt': '1',
#       'impDlr': '52',
#       'statCd': 'AN',
#       'statCdCntnKor1': '네덜란드 열도',
#       'year': '2025.01'},
#      {'balPayments': '-194331',
#       'expCnt': '1',
#       'expDlr': '20891',
#       'impCnt': '7',
#       'impDlr': '215222',
#       'statCd': 'MC',
#       'statCdCntnKor1': '모나코',
#       'year': '2025.01'},
#      {'balPayments': '-8008',
#       'expCnt': '2',
#       'expDlr': '19864',
#       'impCnt': '1',
#       'impDlr': '27872',
#       'statCd': 'CF',
#       'statCdCntnKor1': '중앙아프리카공화국',
#       'year': '2025.01'},
#      {'balPayments': '17933',
#       'expCnt': '2',
#       'expDlr': '18022',
#       'impCnt': '1',
#       'impDlr': '89',
#       'statCd': 'TD',
#       'statCdCntnKor1': '챠드',
#       'year': '2025.01'},
#      {'balPayments': '15869',
#       'expCnt': '11',
#       'expDlr': '15869',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'GI',
#       'statCdCntnKor1': '지브랄타',
#       'year': '2025.01'},
#      {'balPayments': '-2966',
#       'expCnt': '1',
#       'expDlr': '11966',
#       'impCnt': '1',
#       'impDlr': '14932',
#       'statCd': 'TO',
#       'statCdCntnKor1': '통가',
#       'year': '2025.01'},
#      {'balPayments': '7808',
#       'expCnt': '5',
#       'expDlr': '7845',
#       'impCnt': '1',
#       'impDlr': '37',
#       'statCd': 'SX',
#       'statCdCntnKor1': '세인트마틴(생마르탱)',
#       'year': '2025.01'},
#      {'balPayments': '-7897',
#       'expCnt': '2',
#       'expDlr': '5937',
#       'impCnt': '0',
#       'impDlr': '13834',
#       'statCd': 'BL',
#       'statCdCntnKor1': '세인트 바르탤르미',
#       'year': '2025.01'},
#      {'balPayments': '-279729',
#       'expCnt': '1',
#       'expDlr': '2506',
#       'impCnt': '3',
#       'impDlr': '282235',
#       'statCd': 'GL',
#       'statCdCntnKor1': '그린랜드',
#       'year': '2025.01'},
#      {'balPayments': '1854',
#       'expCnt': '6',
#       'expDlr': '1854',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'VA',
#       'statCdCntnKor1': '교황청',
#       'year': '2025.01'},
#      {'balPayments': '-182',
#       'expCnt': '2',
#       'expDlr': '1731',
#       'impCnt': '1',
#       'impDlr': '1913',
#       'statCd': 'KM',
#       'statCdCntnKor1': '코모로스',
#       'year': '2025.01'},
#      {'balPayments': '1160',
#       'expCnt': '1',
#       'expDlr': '1160',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'AI',
#       'statCdCntnKor1': '앙귈라',
#       'year': '2025.01'},
#      {'balPayments': '1084',
#       'expCnt': '1',
#       'expDlr': '1084',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'ER',
#       'statCdCntnKor1': '에리트리아',
#       'year': '2025.01'},
#      {'balPayments': '1019',
#       'expCnt': '7',
#       'expDlr': '1019',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'VI',
#       'statCdCntnKor1': '미령 버진군도',
#       'year': '2025.01'},
#      {'balPayments': '557',
#       'expCnt': '2',
#       'expDlr': '557',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'MS',
#       'statCdCntnKor1': '몬트세라트',
#       'year': '2025.01'},
#      {'balPayments': '415',
#       'expCnt': '4',
#       'expDlr': '415',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'GG',
#       'statCdCntnKor1': '건지',
#       'year': '2025.01'},
#      {'balPayments': '-234',
#       'expCnt': '2',
#       'expDlr': '246',
#       'impCnt': '1',
#       'impDlr': '480',
#       'statCd': 'JE',
#       'statCdCntnKor1': '저어지',
#       'year': '2025.01'},
#      {'balPayments': '4',
#       'expCnt': '1',
#       'expDlr': '4',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'WF',
#       'statCdCntnKor1': '왈라스 & 퓨투나 군도',
#       'year': '2025.01'},
#      {'balPayments': '-8408',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '1',
#       'impDlr': '8408',
#       'statCd': 'BQ',
#       'statCdCntnKor1': '보네르 신트외스타티위스',
#       'year': '2025.01'},
#      {'balPayments': '-46',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '0',
#       'impDlr': '46',
#       'statCd': 'TF',
#       'statCdCntnKor1': '불령 남부지역',
#       'year': '2025.01'},
#      {'balPayments': '-74',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '0',
#       'impDlr': '74',
#       'statCd': 'ST',
#       'statCdCntnKor1': '상토메 프린스페',
#       'year': '2025.01'},
#      {'balPayments': '-12',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '1',
#       'impDlr': '12',
#       'statCd': 'IM',
#       'statCdCntnKor1': '맨섬',
#       'year': '2025.01'},
#      {'balPayments': '-1619',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '1',
#       'impDlr': '1619',
#       'statCd': 'AD',
#       'statCdCntnKor1': '안도라',
#       'year': '2025.01'},
#      {'balPayments': '-1177',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '0',
#       'impDlr': '1177',
#       'statCd': 'CX',
#       'statCdCntnKor1': '크리스마스 아일랜드',
#       'year': '2025.01'},
#      {'balPayments': '-129121',
#       'expCnt': '0',
# ...
#       'year': '2025.04'},
#      {'balPayments': '134',
#       'expCnt': '1',
#       'expDlr': '134',
#       'impCnt': '0',
#       'impDlr': '0',
#       'statCd': 'JE',
#       'statCdCntnKor1': '저어지',
#       'year': '2025.04'},
#      {'balPayments': '-50828',
#       'expCnt': '2',
#       'expDlr': '78',
#       'impCnt': '4',
#       'impDlr': '50906',
#       'statCd': 'MC',
#       'statCdCntnKor1': '모나코',
#       'year': '2025.04'},
#      {'balPayments': '-191',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '0',
#       'impDlr': '191',
#       'statCd': 'HM',
#       'statCdCntnKor1': '허드 앤 맥도날드 군도',
#       'year': '2025.04'},
#      {'balPayments': '-13',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '1',
#       'impDlr': '13',
#       'statCd': 'CX',
#       'statCdCntnKor1': '크리스마스 아일랜드',
#       'year': '2025.04'},
#      {'balPayments': '-3138',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '2',
#       'impDlr': '3138',
#       'statCd': 'CC',
#       'statCdCntnKor1': '코스 군도',
#       'year': '2025.04'},
#      {'balPayments': '-10265',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '3',
#       'impDlr': '10265',
#       'statCd': 'LS',
#       'statCdCntnKor1': '레소토',
#       'year': '2025.04'},
#      {'balPayments': '-486859',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '12',
#       'impDlr': '486859',
#       'statCd': 'AQ',
#       'statCdCntnKor1': '안타티카',
#       'year': '2025.04'},
#      {'balPayments': '-9722',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '1',
#       'impDlr': '9722',
#       'statCd': 'UM',
#       'statCdCntnKor1': '마이너 아우틀링 합중국 군도',
#       'year': '2025.04'},
#      {'balPayments': '-9390',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '1',
#       'impDlr': '9390',
#       'statCd': 'BL',
#       'statCdCntnKor1': '세인트 바르탤르미',
#       'year': '2025.04'},
#      {'balPayments': '-13944',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '0',
#       'impDlr': '13944',
#       'statCd': 'TK',
#       'statCdCntnKor1': '토켈라우',
#       'year': '2025.04'},
#      {'balPayments': '-31',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '1',
#       'impDlr': '31',
#       'statCd': 'CK',
#       'statCdCntnKor1': '쿡 아일랜드',
#       'year': '2025.04'},
#      {'balPayments': '-42342',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '1',
#       'impDlr': '42342',
#       'statCd': 'IM',
#       'statCdCntnKor1': '맨섬',
#       'year': '2025.04'},
#      {'balPayments': '-13300',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '1',
#       'impDlr': '13300',
#       'statCd': 'SH',
#       'statCdCntnKor1': '세인트 헬레나',
#       'year': '2025.04'},
#      {'balPayments': '-21443',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '5',
#       'impDlr': '21443',
#       'statCd': 'NU',
#       'statCdCntnKor1': '니우에',
#       'year': '2025.04'},
#      {'balPayments': '-2774',
#       'expCnt': '0',
#       'expDlr': '0',
#       'impCnt': '0',
#       'impDlr': '2774',
#       'statCd': 'TF',
#       'statCdCntnKor1': '불령 남부지역',
#       'year': '2025.04'},
#      {'balPayments': '-892702248',
#       'expCnt': '92179',
#       'expDlr': '10446428166',
#       'impCnt': '1612762',
#       'impDlr': '11339130414',
#       'statCd': 'CN',
#       'statCdCntnKor1': '중국',
#       'year': '2025.05'},
#      {'balPayments': '3263345968',
#       'expCnt': '223341',
#       'expDlr': '10036995110',
#       'impCnt': '1511873',
#       'impDlr': '6773649142',
#       'statCd': 'US',
#       'statCdCntnKor1': '미국',
#       'year': '2025.05'},
#      {'balPayments': '2869820092',
#       'expCnt': '59640',
#       'expDlr': '5236200221',
#       'impCnt': '195657',
#       'impDlr': '2366380129',
#       'statCd': 'VN',
#       'statCdCntnKor1': '베트남',
#       'year': '2025.05'},
#      {'balPayments': '1337355804',
#       'expCnt': '42464',
#       'expDlr': '3773435249',
#       'impCnt': '22612',
#       'impDlr': '2436079445',
#       'statCd': 'TW',
#       'statCdCntnKor1': '대만',
#       'year': '2025.05'},
#      {'balPayments': '2733983219',
#       'expCnt': '24199',
#       'expDlr': '2855506442',
#       'impCnt': '240478',
#       'impDlr': '121523223',
#       'statCd': 'HK',
#       'statCdCntnKor1': '홍콩',
#       'year': '2025.05'},
#      {'balPayments': '-1186632845',
#       'expCnt': '142289',
#       'expDlr': '2372098635',
#       'impCnt': '410928',
#       'impDlr': '3558731480',
#       'statCd': 'JP',
#       'statCdCntnKor1': '일본',
#       'year': '2025.05'},
#      {'balPayments': '987158036',
#       'expCnt': '19378',
#       'expDlr': '1615438483',
#       'impCnt': '13368',
#       'impDlr': '628280447',
#       'statCd': 'IN',
#       'statCdCntnKor1': '인도',
#       'year': '2025.05'},
#      {'balPayments': '726032683',
#       'expCnt': '49733',
#       'expDlr': '1587493146',
#       'impCnt': '19367',
#       'impDlr': '861460463',
#       'statCd': 'SG',
#       'statCdCntnKor1': '싱가포르',
#       'year': '2025.05'},
#      {'balPayments': '-1337236088',
#       'expCnt': '20178',
#       'expDlr': '1136166281',
#       'impCnt': '44107',
#       'impDlr': '2473402369',
#       'statCd': 'AU',
#       'statCdCntnKor1': '호주',
#       'year': '2025.05'},
#      {'balPayments': '-900323881',
#       'expCnt': '15268',
#       'expDlr': '1075108269',
#       'impCnt': '198356',
#       'impDlr': '1975432150',
#       'statCd': 'DE',
#       'statCdCntnKor1': '독일',
#       'year': '2025.05'},
#      {'balPayments': '364403342',
#       'expCnt': '18620',
#       'expDlr': '1067190930',
#       'impCnt': '7535',
#       'impDlr': '702787588',
#       'statCd': 'MX',
#       'statCdCntnKor1': '멕시코',
#       'year': '2025.05'},
#      {'balPayments': '-77149478',
#       'expCnt': '33981',
#       'expDlr': '1026451597',
#       'impCnt': '12688',
#       'impDlr': '1103601075',
#       'statCd': 'MY',
#       'statCdCntnKor1': '말레이시아',
#       'year': '2025.05'},
#      {'balPayments': '409208593',
#       'expCnt': '19960',
#       'expDlr': '959681671',
#       'impCnt': '39410',
#       'impDlr': '550473078',
#       'statCd': 'CA',
#       'statCdCntnKor1': '캐나다',
#       'year': '2025.05'},
#      {'balPayments': '585358546',
#       'expCnt': '28938',
#       'expDlr': '863479029',
#       'impCnt': '6401',
#       'impDlr': '278120483',
#       'statCd': 'PH',
#       'statCdCntnKor1': '필리핀',
#       'year': '2025.05'},
#      {'balPayments': '205504058',
#       'expCnt': '9940',
#       'expDlr': '838724202',
#       'impCnt': '5831',
#       'impDlr': '633220144',
#       'statCd': 'NL',
#       'statCdCntnKor1': '네덜란드',
#       'year': '2025.05'},
#      {'balPayments': '537843668',
#       'expCnt': '12900',
#       'expDlr': '682919623',
#       'impCnt': '2740',
#       'impDlr': '145075955',
#       'statCd': 'TR',
#       'statCdCntnKor1': '튀르키예',
#       'year': '2025.05'},
#      {'balPayments': '572082291',
#       'expCnt': '6186',
#       'expDlr': '654532921',
#       'impCnt': '2257',
#       'impDlr': '82450630',
#       'statCd': 'PL',
#       'statCdCntnKor1': '폴란드',
#       'year': '2025.05'},
#      {'balPayments': '71193467',
#       'expCnt': '17518',
#       'expDlr': '636380654',
#       'impCnt': '54186',
#       'impDlr': '565187187',
#       'statCd': 'TH',
#       'statCdCntnKor1': '태국',
#       'year': '2025.05'},
#      {'balPayments': '264052989',
#       'expCnt': '17711',
#       'expDlr': '605684116',
#       'impCnt': '20227',
#       'impDlr': '341631127',
#       'statCd': 'GB',
#       'statCdCntnKor1': '영국',
#       'year': '2025.05'},
#      {'balPayments': '-296128332',
#       'expCnt': '12900',
#       'expDlr': '567589858',
#       'impCnt': '9794',
#       'impDlr': '863718190',
#       'statCd': 'ID',
#       'statCdCntnKor1': '인도네시아',
#       'year': '2025.05'},
#      {'balPayments': '-103057838',
#       'expCnt': '6646',
#       'expDlr': '500966736',
#       'impCnt': '22379',
#       'impDlr': '604024574',
#       'statCd': 'FR',
#       'statCdCntnKor1': '프랑스',
#       'year': '2025.05'},
#      {'balPayments': '-380545489',
#       'expCnt': '12464',
#       'expDlr': '410029330',
#       'impCnt': '511',
#       'impDlr': '790574819',
#       'statCd': 'AE',
#       'statCdCntnKor1': '아랍에미리트 연합',
#       'year': '2025.05'},
#      {'balPayments': '-125202072',
#       'expCnt': '8760',
#       'expDlr': '405682039',
#       'impCnt': '2126',
#       'impDlr': '530884111',
#       'statCd': 'BR',
#       'statCdCntnKor1': '브라질',
#       'year': '2025.05'},
#      {'balPayments': '392051473',
#       'expCnt': '79',
#       'expDlr': '392059919',
#       'impCnt': '22',
#       'impDlr': '8446',
#       'statCd': 'LR',
#       'statCdCntnKor1': '라이베리아',
#       'year': '2025.05'},
#      {'balPayments': '335840722',
#       'expCnt': '2278',
#       'expDlr': '390045715',
#       'impCnt': '1449',
#       'impDlr': '54204993',
#       'statCd': 'HU',
#       'statCdCntnKor1': '헝가리',
#       'year': '2025.05'},
#      {'balPayments': '-191230755',
#       'expCnt': '6041',
#       'expDlr': '388094503',
#       'impCnt': '31635',
#       'impDlr': '579325258',
#       'statCd': 'IT',
#       'statCdCntnKor1': '이탈리아',
#       'year': '2025.05'},
#      {'balPayments': '-136865571',
#       'expCnt': '7483',
#       'expDlr': '373711833',
#       'impCnt': '1392',
#       'impDlr': '510577404',
#       'statCd': 'RU',
#       'statCdCntnKor1': '러시아 연방',
#       'year': '2025.05'},
#      {'balPayments': '218451441',
#       'expCnt': '2695',
#       'expDlr': '311615980',
#       'impCnt': '2294',
#       'impDlr': '93164539',
#       'statCd': 'BE',
#       'statCdCntnKor1': '벨기에',
#       'year': '2025.05'},
#      {'balPayments': '-1761378064',
#       'expCnt': '4064',
#       'expDlr': '293127546',
#       'impCnt': '460',
#       'impDlr': '2054505610',
#       'statCd': 'SA',
#       'statCdCntnKor1': '사우디아라비아',
#       'year': '2025.05'},
#      {'balPayments': '277918775',
#       'expCnt': '38',
#       'expDlr': '278003840',
#       'impCnt': '18',
#       'impDlr': '85065',
#       'statCd': 'MH',
#       'statCdCntnKor1': '마샬군도',
#       'year': '2025.05'},
#      {'balPayments': '-46452494',
#       'expCnt': '4897',
#       'expDlr': '273139255',
#       'impCnt': '69',
#       'impDlr': '319591749',
#       'statCd': 'KZ',
#       'statCdCntnKor1': '카자흐스탄',
#       'year': '2025.05'},
#      {'balPayments': '37396512',
#       'expCnt': '4873',
#       'expDlr': '265977703',
#       'impCnt': '9197',
#       'impDlr': '228581191',
#       'statCd': 'ES',
#       'statCdCntnKor1': '스페인',
#       'year': '2025.05'},
#      {'balPayments': '264269615',
#       'expCnt': '9649',
#       'expDlr': '264347809',
#       'impCnt': '5',
#       'impDlr': '78194',
#       'statCd': 'KG',
#       'statCdCntnKor1': '키르기스스탄',
#       'year': '2025.05'},
#      {'balPayments': '62395241',
#       'expCnt': '3116',
#       'expDlr': '253752795',
#       'impCnt': '32366',
#       'impDlr': '191357554',
#       'statCd': 'NZ',
#       'statCdCntnKor1': '뉴질랜드',
#       'year': '2025.05'},
#      {'balPayments': '153532440',
#       'expCnt': '1599',
#       'expDlr': '252896214',
#       'impCnt': '2166',
#       'impDlr': '99363774',
#       'statCd': 'DK',
#       'statCdCntnKor1': '덴마크',
#       'year': '2025.05'},
#      {'balPayments': '164622403',
#       'expCnt': '1844',
#       'expDlr': '243200677',
#       'impCnt': '1621',
#       'impDlr': '78578274',
#       'statCd': 'SK',
#       'statCdCntnKor1': '슬로바키아',
#       'year': '2025.05'},
#      {'balPayments': '134707149',
#       'expCnt': '2813',
#       'expDlr': '231880566',
#       'impCnt': '3406',
#       'impDlr': '97173417',
#       'statCd': 'CZ',
#       'statCdCntnKor1': '체코공화국',
#       'year': '2025.05'},
#      {'balPayments': '192763588',
#       'expCnt': '1106',
#       'expDlr': '194374591',
#       'impCnt': '107',
#       'impDlr': '1611003',
#       'statCd': 'PA',
#       'statCdCntnKor1': '파나마',
#       'year': '2025.05'},
#      {'balPayments': '-175596505',
#       'expCnt': '2859',
#       'expDlr': '164443824',
#       'impCnt': '4525',
#       'impDlr': '340040329',
#       'statCd': 'CH',
#       'statCdCntnKor1': '스위스',
#       'year': '2025.05'},
#      {'balPayments': '143051446',
#       'expCnt': '3118',
#       'expDlr': '144208468',
#       'impCnt': '1012',
#       'impDlr': '1157022',
#       'statCd': 'MN',
#       'statCdCntnKor1': '몽골',
#       'year': '2025.05'},
#      {'balPayments': '112987892',
#       'expCnt': '2245',
#       'expDlr': '143311410',
#       'impCnt': '1518',
#       'impDlr': '30323518',
#       'statCd': 'BD',
#       'statCdCntnKor1': '방글라데시',
#       'year': '2025.05'},
#      {'balPayments': '-8563309',
#       'expCnt': '5403',
#       'expDlr': '140593645',
#       'impCnt': '1638',
#       'impDlr': '149156954',
#       'statCd': 'IL',
#       'statCdCntnKor1': '이스라엘',
#       'year': '2025.05'},
#      {'balPayments': '131573376',
#       'expCnt': '1291',
#       'expDlr': '139403200',
#       'impCnt': '350',
#       'impDlr': '7829824',
#       'statCd': 'GR',
#       'statCdCntnKor1': '그리스',
#       'year': '2025.05'},
#      {'balPayments': '130181663',
#       'expCnt': '255',
#       'expDlr': '138300207',
#       'impCnt': '105',
#       'impDlr': '8118544',
#       'statCd': 'MT',
#       'statCdCntnKor1': '몰타',
#       'year': '2025.05'},
#      {'balPayments': '32085895',
#       'expCnt': '1564',
#       'expDlr': '127518988',
#       'impCnt': '1198',
#       'impDlr': '95433093',
#       'statCd': 'CO',
#       'statCdCntnKor1': '콜롬비아',
#       'year': '2025.05'},
#      {'balPayments': '121711175',
#       'expCnt': '1720',
#       'expDlr': '122759850',
#       'impCnt': '81',
#       'impDlr': '1048675',
#       'statCd': 'UZ',
#       'statCdCntnKor1': '우즈베키스탄',
#       'year': '2025.05'},
#      {'balPayments': '-255435621',
#       'expCnt': '2467',
#       'expDlr': '107524716',
#       'impCnt': '1296',
#       'impDlr': '362960337',
#       'statCd': 'CL',
#       'statCdCntnKor1': '칠레',
#       'year': '2025.05'},
#      {'balPayments': '-68409915',
#       'expCnt': '1834',
#       'expDlr': '100410801',
#       'impCnt': '3249',
#       'impDlr': '168820716',
#       'statCd': 'SE',
#       'statCdCntnKor1': '스웨덴',
#       'year': '2025.05'},
#      {'balPayments': '-704703579',
#       'expCnt': '948',
#       'expDlr': '97966423',
#       'impCnt': '111',
#       'impDlr': '802670002',
#       'statCd': 'IQ',
#       'statCdCntnKor1': '이라크',
#       'year': '2025.05'},
#      {'balPayments': '80522562',
#       'expCnt': '1517',
#       'expDlr': '93441173',
#       'impCnt': '627',
#       'impDlr': '12918611',
#       'statCd': 'PK',
#       'statCdCntnKor1': '파키스탄',
#       'year': '2025.05'},
#      {'balPayments': '-60054091',
#       'expCnt': '2196',
#       'expDlr': '90307327',
#       'impCnt': '2548',
#       'impDlr': '150361418',
#       'statCd': 'AT',
#       'statCdCntnKor1': '오스트리아',
#       'year': '2025.05'},
#      {'balPayments': '76158097',
#       'expCnt': '676',
#       'expDlr': '88291154',
#       'impCnt': '387',
#       'impDlr': '12133057',
#       'statCd': 'SI',
#       'statCdCntnKor1': '슬로베니아',
#       'year': '2025.05'},
#      {'balPayments': '82446082',
#       'expCnt': '2138',
#       'expDlr': '87295078',
#       'impCnt': '215',
#       'impDlr': '4848996',
#       'statCd': 'EG',
#       'statCdCntnKor1': '이집트',
#       'year': '2025.05'},
#      {'balPayments': '-53674592',
#       'expCnt': '1038',
#       'expDlr': '86903865',
#       'impCnt': '1163',
#       'impDlr': '140578457',
#       'statCd': 'IE',
#       'statCdCntnKor1': '아일랜드',
#       'year': '2025.05'},
#      {'balPayments': '62441746',
#       'expCnt': '150',
#       'expDlr': '62442046',
#       'impCnt': '1',
#       'impDlr': '300',
#       'statCd': 'AO',
#       'statCdCntnKor1': '앙골라',
#       'year': '2025.05'},
#      {'balPayments': '35142021',
#       'expCnt': '1102',
#       'expDlr': '61925365',
#       'impCnt': '4622',
#       'impDlr': '26783344',
#       'statCd': 'PT',
#       'statCdCntnKor1': '포루투갈',
#       'year': '2025.05'},
#      {'balPayments': '-61364113',
#       'expCnt': '1097',
#       'expDlr': '57179884',
#       'impCnt': '2295',
#       'impDlr': '118543997',
#       'statCd': 'NO',
#       'statCdCntnKor1': '노르웨이',
#       'year': '2025.05'},
#      {'balPayments': '42082882',
#       'expCnt': '1163',
#       'expDlr': '56255835',
#       'impCnt': '174',
#       'impDlr': '14172953',
#       'statCd': 'UA',
#       'statCdCntnKor1': '우크라이나',
#       'year': '2025.05'},
#      {'balPayments': '-73458484',
#       'expCnt': '1658',
#       'expDlr': '56248706',
#       'impCnt': '363',
#       'impDlr': '129707190',
#       'statCd': 'ZA',
#       'statCdCntnKor1': '남아프리카공화국',
#       'year': '2025.05'},
#      ...]}}}}

# %%
# 원하는 데이터 추출
# 이 경로는 API 응답 데이터의 구조에 따라 다르므로, API 문서 참고해 키를 확인해야 됨.
result = xml_dict['response']['body']['items']['item']

print(result)
# Out:
# [{'balPayments': '3443225952', 'expCnt': '193178', 'expDlr': '9282566788', 'impCnt': '1416582', 'impDlr': '5839340836', 'statCd': 'US', 'statCdCntnKor1': '미국', 'year': '2025.01'}, {'balPayments': '-2004621045', 'expCnt': '91388', 'expDlr': '9204172269', 'impCnt': '1225173', 'impDlr': '11208793314', 'statCd': 'CN', 'statCdCntnKor1': '중국', 'year': '2025.01'}, {'balPayments': '1792245180', 'expCnt': '57209', 'expDlr': '4356972160', 'impCnt': '145132', 'impDlr': '2564726980', 'statCd': 'VN', 'statCdCntnKor1': '베트남', 'year': '2025.01'}, {'balPayments': '210300569', 'expCnt': '34078', 'expDlr': '2438188048', 'impCnt': '20022', 'impDlr': '2227887479', 'statCd': 'TW', 'statCdCntnKor1': '대만', 'year': '2025.01'}, {'balPayments': '-1223548429', 'expCnt': '146929', 'expDlr': '2363796881', 'impCnt': '344783', 'impDlr': '3587345310', 'statCd': 'JP', 'statCdCntnKor1': '일본', 'year': '2025.01'}, {'balPayments': '1502111293', 'expCnt': '18142', 'expDlr': '1685484400', 'impCnt': '145075', 'impDlr': '183373107', 'statCd': 'HK', 'statCdCntnKor1': '홍콩', 'year': '2025.01'}, {'balPayments': '928096823', 'expCnt': '18165', 'expDlr': '1463920945', 'impCnt': '10408', 'impDlr': '535824122', 'statCd': 'IN', 'statCdCntnKor1': '인도', 'year': '2025.01'}, {'balPayments': '134187136', 'expCnt': '42253', 'expDlr': '1162019513', 'impCnt': '18404', 'impDlr': '1027832377', 'statCd': 'SG', 'statCdCntnKor1': '싱가포르', 'year': '2025.01'}, {'balPayments': '179175548', 'expCnt': '15031', 'expDlr': '947164179', 'impCnt': '6035', 'impDlr': '767988631', 'statCd': 'MX', 'statCdCntnKor1': '멕시코', 'year': '2025.01'}, {'balPayments': '-429397344', 'expCnt': '26784', 'expDlr': '921581753', 'impCnt': '10823', 'impDlr': '1350979097', 'statCd': 'MY', 'statCdCntnKor1': '말레이시아', 'year': '2025.01'}, {'balPayments': '-1997255017', 'expCnt': '15080', 'expDlr': '909426750', 'impCnt': '46098', 'impDlr': '2906681767', 'statCd': 'AU', 'statCdCntnKor1': '호주', 'year': '2025.01'}, {'balPayments': '651665145', 'expCnt': '25805', 'expDlr': '880737363', 'impCnt': '5154', 'impDlr': '229072218', 'statCd': 'PH', 'statCdCntnKor1': '필리핀', 'year': '2025.01'}, {'balPayments': '-620017969', 'expCnt': '12862', 'expDlr': '769583494', 'impCnt': '182280', 'impDlr': '1389601463', 'statCd': 'DE', 'statCdCntnKor1': '독일', 'year': '2025.01'}, {'balPayments': '684513428', 'expCnt': '5877', 'expDlr': '765206162', 'impCnt': '2266', 'impDlr': '80692734', 'statCd': 'PL', 'statCdCntnKor1': '폴란드', 'year': '2025.01'}, {'balPayments': '737928915', 'expCnt': '26', 'expDlr': '737986093', 'impCnt': '19', 'impDlr': '57178', 'statCd': 'MH', 'statCdCntnKor1': '마샬군도', 'year': '2025.01'}, {'balPayments': '192078215', 'expCnt': '18111', 'expDlr': '734752287', 'impCnt': '35388', 'impDlr': '542674072', 'statCd': 'CA', 'statCdCntnKor1': '캐나다', 'year': '2025.01'}, {'balPayments': '554082782', 'expCnt': '14543', 'expDlr': '662302204', 'impCnt': '2556', 'impDlr': '108219422', 'statCd': 'TR', 'statCdCntnKor1': '튀르키예', 'year': '2025.01'}, {'balPayments': '163581432', 'expCnt': '17639', 'expDlr': '624224814', 'impCnt': '42817', 'impDlr': '460643382', 'statCd': 'TH', 'statCdCntnKor1': '태국', 'year': '2025.01'}, {'balPayments': '224066443', 'expCnt': '16092', 'expDlr': '556946982', 'impCnt': '29145', 'impDlr': '332880539', 'statCd': 'GB', 'statCdCntnKor1': '영국', 'year': '2025.01'}, {'balPayments': '-562973689', 'expCnt': '12319', 'expDlr': '551655213', 'impCnt': '8931', 'impDlr': '1114628902', 'statCd': 'ID', 'statCdCntnKor1': '인도네시아', 'year': '2025.01'}, {'balPayments': '-6266128', 'expCnt': '6309', 'expDlr': '476678490', 'impCnt': '19289', 'impDlr': '482944618', 'statCd': 'FR', 'statCdCntnKor1': '프랑스', 'year': '2025.01'}, {'balPayments': '-26294992', 'expCnt': '8910', 'expDlr': '458101813', 'impCnt': '5392', 'impDlr': '484396805', 'statCd': 'NL', 'statCdCntnKor1': '네덜란드', 'year': '2025.01'}, {'balPayments': '457783206', 'expCnt': '57', 'expDlr': '457792875', 'impCnt': '29', 'impDlr': '9669', 'statCd': 'LR', 'statCdCntnKor1': '라이베리아', 'year':  ...

# %%
# 딕셔너리를 데이터 프레임으로 ㅕㄴ환
im_export = pd.json_normalize(result)
im_export.head()
# Out:
#    balPayments  expCnt      expDlr   impCnt       impDlr statCd  \
# 0   3443225952  193178  9282566788  1416582   5839340836     US
# 1  -2004621045   91388  9204172269  1225173  11208793314     CN
# 2   1792245180   57209  4356972160   145132   2564726980     VN
# 3    210300569   34078  2438188048    20022   2227887479     TW
# 4  -1223548429  146929  2363796881   344783   3587345310     JP
#
#   statCdCntnKor1     year
# 0             미국  2025.01
# 1             중국  2025.01
# 2            베트남  2025.01
# 3             대만  2025.01
# 4             일본  2025.01

# %% [markdown]
# **데이터셋 설명**
#
# - balPayments: 무역수지(달러)
# - expCnt: 수출건수
# - expDlr: 수출금액(달러)
# - impCnt: 수입건수
# - impDlr: 수입금액(달러)
# - statCd: 국가코드
# - statCdCntnKor1: 국가
# - year: 기간

# %% [markdown]
# ### 1.1.2.데이터 분석
#
# - Pandas는 숫자가 크면 숫자를 2.805000e+03 형태로 표시한다.
# - 가독성을 높이기 위해 이후 숫자 출력은 소수점 두자리를 갖는 일반 형태로 표시하게 한다.

# %%
# 소수점 전처리
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
im_export.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2830 entries, 0 to 2829
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   balPayments     2830 non-null   str
#  1   expCnt          2830 non-null   str
#  2   expDlr          2830 non-null   str
#  3   impCnt          2830 non-null   str
#  4   impDlr          2830 non-null   str
#  5   statCd          2830 non-null   str
#  6   statCdCntnKor1  2830 non-null   str
#  7   year            2830 non-null   str
# dtypes: str(8)
# memory usage: 177.0 KB

# %% [markdown]
# **1) 데이터 탐색 및 전처리**
#
# - 열 이름, 데이터 형식 등 열 정보 확인

# %%
im_export.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2830 entries, 0 to 2829
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   balPayments     2830 non-null   str
#  1   expCnt          2830 non-null   str
#  2   expDlr          2830 non-null   str
#  3   impCnt          2830 non-null   str
#  4   impDlr          2830 non-null   str
#  5   statCd          2830 non-null   str
#  6   statCdCntnKor1  2830 non-null   str
#  7   year            2830 non-null   str
# dtypes: str(8)
# memory usage: 177.0 KB

# %% [markdown]
# - 이후 수치 비교를 위해 숫자 데이터를 int64로 변환
# - 대상 열: balPayments, expCnt, expDlr, impCnt, impDlr
# - 구문 예) df['Money'].astype('int64')

# %%
cols = ['balPayments', 'expCnt', 'expDlr', 'impCnt', 'impDlr']

im_export[cols] = im_export[cols].astype('int64')

im_export.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2830 entries, 0 to 2829
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   balPayments     2830 non-null   int64
#  1   expCnt          2830 non-null   int64
#  2   expDlr          2830 non-null   int64
#  3   impCnt          2830 non-null   int64
#  4   impDlr          2830 non-null   int64
#  5   statCd          2830 non-null   str
#  6   statCdCntnKor1  2830 non-null   str
#  7   year            2830 non-null   str
# dtypes: int64(5), str(3)
# memory usage: 177.0 KB

# %%
im_export.describe()
# Out:
#          balPayments    expCnt         expDlr     impCnt         impDlr
# count        2830.00   2830.00        2830.00    2830.00        2830.00
# mean     27362076.73   4870.13   250646658.94   19270.59   223284582.21
# std     477349207.86  23761.40  1105703183.57  145392.20   978743396.01
# min   -2459852528.00      0.00           0.00       0.00           0.00
# 25%       -209850.25     16.25      556300.00       2.00       10265.75
# 50%        566795.50    141.00     5100655.00      21.00     1331979.50
# 75%       9670287.50   1117.75    56715844.00     373.75    46289235.50
# max    5717645732.00 459337.00 12964960895.00 1945296.00 13729115193.00

# %% [markdown]
# **2) 2025년 12월 무역수지 TOP 10**
#
# - 2025년 12월 데이터를 별도로 추출하여 **im_export12** 데이터프레임을 만듭니다.
# - 무역수지(balPayments)를 기준으로 내림차순 정렬합니다.
# - 정렬 결과로 어긋난 순서의 인덱스를 깔끔하게 초기화합니다.
# - 상위 10개 행만 출력해 2025년 12월 무역수지 TOP 10을 확인합니다.

# %%
im_export12 = im_export.loc[im_export['year'] == '2025.12']

im_export12 = im_export12.sort_values(by='balPayments', ascending=False)

im_export12
# Out:
#       balPayments  expCnt       expDlr   impCnt       impDlr statCd  \
# 2595   5561530992  232653  12335136415  1267690   6773605423     US
# 2598   4280632585   38739   4624113700   391772    343481115     HK
# 2596   3332483885   67807   6281464305   233578   2948980420     VN
# 2597   2256773042   68113   5131207266    25051   2874434224     TW
# 2601   1200481846   21241   1719209860    13877    518728014     IN
# ...           ...     ...          ...      ...          ...    ...
# 2594   -764154298  100213  12964960895  1945296  13729115193     CN
# 2613  -1298255706    5185    617378019      448   1915633725     SA
# 2611  -1540757528   16390    674509732   163783   2215267260     DE
# 2603  -1564486575   26009   1400777577    37609   2965264152     AU
# 2599  -2216475177  274877   2456896027   444364   4673371204     JP
#
#      statCdCntnKor1     year
# 2595             미국  2025.12
# 2598             홍콩  2025.12
# 2596            베트남  2025.12
# 2597             대만  2025.12
# 2601             인도  2025.12
# ...             ...      ...
# 2594             중국  2025.12
# 2613        사우디아라비아  2025.12
# 2611             독일  2025.12
# 2603             호주  2025.12
# 2599             일본  2025.12
#
# [236 rows x 8 columns]

# %%
im_export12.reset_index(drop=True, inplace=True)

im_export12.head(10)
# Out:
#    balPayments  expCnt       expDlr   impCnt      impDlr statCd  \
# 0   5561530992  232653  12335136415  1267690  6773605423     US
# 1   4280632585   38739   4624113700   391772   343481115     HK
# 2   3332483885   67807   6281464305   233578  2948980420     VN
# 3   2256773042   68113   5131207266    25051  2874434224     TW
# 4   1200481846   21241   1719209860    13877   518728014     IN
# 5   1033101128   54471   2069320523    16861  1036219395     SG
# 6   1008638544      43   1008679079       12       40535     MH
# 7    896992758   33414   1203925892     6328   306933134     PH
# 8    594935421    6918    744839034     3206   149903613     TR
# 9    439455893   16482   1050832758     8690   611376865     MX
#
#   statCdCntnKor1     year
# 0             미국  2025.12
# 1             홍콩  2025.12
# 2            베트남  2025.12
# 3             대만  2025.12
# 4             인도  2025.12
# 5           싱가포르  2025.12
# 6           마샬군도  2025.12
# 7            필리핀  2025.12
# 8           튀르키예  2025.12
# 9            멕시코  2025.12
