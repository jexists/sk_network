# %%
# 라이브러리 불러오기
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver import Keys

# %%
driver = webdriver.Chrome()
url = 'https://www.youtube.com/watch?v=jNQXAC9IVRw'
driver.get(url)

# %%
# 일시정지(플레이) 버튼 클릭

play_button = driver.find_element(By.CSS_SELECTOR, ".ytp-play-button.ytp-button")
play_button.click()

# %%
comment_list = []
content_text = driver.find_elements(By.ID, 'content-text')
for x in content_text:
  comment_list.append(x.text)

# %%
comment_list
# Out:
# ["We're so honored that the first ever YouTube video was filmed here!",
#  'Who is watching this April 13th 2026?',
#  '"Who is watching this video from 12.04.26?"',
#  'Why is this recommended 20 years later',
#  '2005 me at the zoo\n2020 me at the zoom',
#  'This guys is the only person who has the rights to say "first" on youtube.',
#  'Honestly so glad to hear that Jawed agrees that removing dislikes is stupid.',
#  'Who is watching this on April 14 2026?',
#  'Wow, still in your recommended in 2021? Nice! Yay \nWhat? 123,000 likes?',
#  'Seeing "20 years ago" on a YouTube video makes me feel a certain type of way',
#  "wow, my birthday is the same day as YouTube's first video lol",
#  'I got this recommended today ... AND SO DID YOU!\n ',
#  'I feel like Neil Armstrong just gave me a shoutout  ... thank you   @jawed',
#  'If he uploads another video with the title: Me leaving the zoo, that will be the end of YouTube',
#  'Almost 21 years old',
#  'This started it all...... bruh ',
#  'The first video on Youtube appears in everyones recommended, NICE.',
#  'Thank you youtube recommended ',
#  '10 days from now, this video will be old enough to drink legally (in the US).',
#  'YouTube recommendation never lets me forget about this legend dhjkgc']

# %%
len(comment_list)
# Out:
# 20

# %%
# 댓글 200개 이상 수집
comment_number = 200
while True:
  content_text = driver.find_elements(By.ID, 'content-text')
  content_number = len(content_text)
  print(content_number, '만큼 수집했습니다. ')
  if content_number < comment_number:
    driver.find_element(By.CSS_SELECTOR, 'body').send_keys(Keys.END)
    time.sleep(1)
  else:
    break

comment_list = []

for x in content_text:
  comment_list.append(x.text)
# Out:
# 219 만큼 수집했습니다.
# [<selenium.webdriver.remote.webelement.WebElement (session="3eea66ad2bd9efdbb9c0d35606952f04", element="f.7CB70F477104765E35B6621DD52A46FB.d.3610EAE20BA35A6FE81E317287AE159F.e.5677")>, <selenium.webdriver.remote.webelement.WebElement (session="3eea66ad2bd9efdbb9c0d35606952f04", element="f.7CB70F477104765E35B6621DD52A46FB.d.3610EAE20BA35A6FE81E317287AE159F.e.5928")>, <selenium.webdriver.remote.webelement.WebElement (session="3eea66ad2bd9efdbb9c0d35606952f04", element="f.7CB70F477104765E35B6621DD52A46FB.d.3610EAE20BA35A6FE81E317287AE159F.e.6161")>, <selenium.webdriver.remote.webelement.WebElement (session="3eea66
287AE159F.e.9290")>, <selenium.webdriver.remote.webelement.WebElement (session="3eea66ad2bd9efdbb9c0d35606952f04", element="f.7CB70F477104765E35B6621DD52A46FB.d.3610EAE20BA35A6FE81E317287AE159F.e.9569")>, <selenium.webdriver.remote.webelement.WebElement (session="3eea66ad2bd9efdbb9c0d35606952f04", element="f.7CB70F477104765E35B6621DD52A46FB.d.3610EAE20BA35A6FE81E317287AE159F.e.9846")>, <selenium.webdriver.remote.webelement.WebElement (session="3eea66ad2bd9efdbb9c0d35606952f04", element="f.7CB70F477104765E35B6621DD52A46FB.d.3610EAE20BA35A6FE81E317287AE159F.e.10107")>, <selenium.webdriver.remote.webelement.WebElement (session="3eea66ad2bd9efdbb9c0d35606952f04", element="f.7CB70F477104765E35B6621DD52A46FB.d.3610EAE20BA35A6FE81E317287AE159F.e.10232")>, <selenium.webdriver.remote.webelement.WebElement (session="3eea66ad2bd9efdbb9c0d35606952f04", element="f.7CB70F477104765E35B6621DD52A46FB.d.3610EAE20BA35A6FE81E317287AE159F.e.12352")>, <selenium.webdriver.remote.webelement.WebElement (session="3eea66ad2bd9efdbb9c0d35606952f04", element="f.7CB70F477104765E35B6621DD52 ...

# %%
comment_list[:30]
# Out:
# ["We're so honored that the first ever YouTube video was filmed here!",
#  'Who is watching this April 13th 2026?',
#  '"Who is watching this video from 12.04.26?"',
#  'Why is this recommended 20 years later',
#  '2005 me at the zoo\n2020 me at the zoom',
#  'This guys is the only person who has the rights to say "first" on youtube.',
#  'Honestly so glad to hear that Jawed agrees that removing dislikes is stupid.',
#  'Who is watching this on April 14 2026?',
#  'Wow, still in your recommended in 2021? Nice! Yay \nWhat? 123,000 likes?',
#  'Seeing "20 years ago" on a YouTube video makes me feel a certain type of way',
#  "wow, my birthday is the same day as YouTube's first video lol",
#  'I got this recommended today ... AND SO DID YOU!\n ',
#  'I feel like Neil Armstrong just gave me a shoutout  ... thank you   @jawed',
#  'If he uploads another video with the title: Me leaving the zoo, that will be the end of YouTube',
#  'Almost 21 years old',
#  'This started it all...... bruh ',
#  'The first video on Youtube appears in everyones recommended, NICE.',
#  'Thank you youtube recommended ',
#  '10 days from now, this video will be old enough to drink legally (in the US).',
#  'YouTube recommendation never lets me forget about this legend dhjkgc',
#  'I found the video\nVideo found me',
#  '5 minutes',
#  'Who in 2026 ??? ( 12 April )',
#  'Who in Saturday, April 11th, 2026 is watching this video?',
#  'Who is coming today 13 Apr 2026  ?',
#  'Anyone else just get recommended this video ',
#  'a',
#  'Still better than Jake Paul',
#  'Oi.   2026.  20 anos ',
#  'recommended 15 years later']
