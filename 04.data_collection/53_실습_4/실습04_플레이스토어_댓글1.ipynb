# %%
# 1. 라이브러리 불러오기

# %%
# 2. 드라이버 옵션 설정 및 브라우저 띄우기

# %%
# 3. 주소 이동(플레이스토어 첫 화면)

# %%
# 4. 실제 앱 주소로 이동

# %%
# 5-1. 댓글 수집

# %%
# 5-2. '리뷰 모두 보기' 버튼 클릭

# %%
# 6-1. 리뷰 확인

# %%
# 6-2. 스크롤 다운 후 리뷰 확인

# %%
# 6-3. while 문으로 스크롤 다운 작성

# %%
# 7-1. 리스트로 저장

# %%
# 7-2. 맨 앞 3개의 리뷰 중복으로 인해 제거
