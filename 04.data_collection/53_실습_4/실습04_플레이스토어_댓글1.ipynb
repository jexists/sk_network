# %%
# 라이브러리 불러오기
import time
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys

# %%
# 2. 드라이버 옵션 설정 및 브라우저 띄우기
driver = webdriver.Chrome()

# %%
# 3. 주소 이동(플레이스토어 첫 화면)
url = 'https://play.google.com/store/apps'
driver.get(url)
time.sleep(2)

# %%
# 4. 실제 앱 주소로 이동
driver.find_element(By.CSS_SELECTOR, '.VfPpkd-Bz112c-LgbsSe').click()
time.sleep(2)
keyword = driver.find_element(By.CSS_SELECTOR, '.HWAcU').send_keys('번개장터')
time.sleep(2)
driver.find_element(By.CSS_SELECTOR, '.HWAcU').send_keys(Keys.ENTER)

time.sleep(5)
driver.find_element(By.CSS_SELECTOR, '.XUIuZ .ipRz4 .Qfxief').click()

# %%
# 5-1. 댓글 수집
comment_list = []

list = driver.find_elements(By.CSS_SELECTOR, '.h3YV2d')

print(len(list))

# print(list[0].text.strip())
# Out:
# 3

# %%
# 5-2. '리뷰 모두 보기' 버튼 클릭

time.sleep(5)
driver.find_element(By.CSS_SELECTOR, '#yDmH0d > c-wiz.SSPGKf.Czez9d > div > div > div:nth-child(1) > div > div.wkMJlb.YWi3ub > div > div.qZmL0 > div:nth-child(1) > c-wiz:nth-child(5) > section > div > div.Jwxk6d > div:nth-child(5) > div > div > button').click()

# %%
# 6-1. 리뷰 확인

comment_list = []

all_list = driver.find_elements(By.CSS_SELECTOR, '.h3YV2d')

print(len(all_list))

print(all_list[0].text.strip())
# Out:
# 23
# 왜 안전결제 필수인가요? 판매자를 위한 행위라고는 눈곱만큼도 안느껴지고, 심지어 구매자한테도 불편한 것 같은데 도대체 왜 정책을 바꿨는지 이해가 안 되고 실망스럽습니다. 판매자도 모두 본격적으로 물건 판매하는 판매상들이 아니잖아요. 전국에 있는 평범한 사람들이 소소하게 물건 나누는 것이 본 목적이었던 것 같은데 그것이 무시되는 기분이에요. 2025/ 수수료 6프로? 아니;;;;;;; 어이없음 제대로 공지도 안하고 어느순간 올리시네요? 진짜 사기꾼은 우리가 아니라 번개장터같습니다,,,, 제대로 된 이유도 뭣도 없이 은근슬쩍 사람들 돈 빼먹는 거 진짜 별로네요 최악 이것때문에 플미가 더 판을 치겠어요 안전결제 원하는 구매자-수수료부담하고 안전결제 선택 안전결제 원하지 않는 구매자-계좌 거래 등 선택 하게 만들어야지 정말 여러모로 대단하시네요^^ 지금 올라가 있는 물건들 나가면 진짜 더이상 물건판매 안할 것 같습니다

# %%
# 6-2. 스크롤 다운 후 리뷰 확인

# %%
# 6-3. while 문으로 스크롤 다운 작성

# %%
# 7-1. 리스트로 저장

# %%
# 7-2. 맨 앞 3개의 리뷰 중복으로 인해 제거

# %%
# 브라우저 종료
# driver.quit()
